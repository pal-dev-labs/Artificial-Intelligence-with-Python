# %% [markdown]
# # QUICK RECAP
#
#     Nella scorsa lezione abbiamo visto:
#     - Come importare un file csv in Pandas
#     - Proprietà elementari degli oggetti Dataframe e Series
#     - Come estrarre righe e colonne dai dataframe (il metodo iloc)
#     - Come effettuare lo slicing sulle righe e sulle colonne
#     - Introduzione ai boolean filter. Primi esempi
#     - Primo esempio di plotting di dati estratti dal dataframe

# %% [markdown]
# Per la documentazione di pandas:
#
# https://pandas.pydata.org/docs/getting_started/index.html

# %%
import pandas as pd

# %% [markdown]
# # DATASET
#
# Utilizzeremo ora un dataset contenente diversi attributi dei calciatori
#
# <img src="fig/dataset.png">
#
#
# https://sofifa.com/

# %%
url = 'https://raw.githubusercontent.com/giandopal/Artificial-Intelligence-with-Python/main/data/players_20.csv'
players = pd.read_csv(url)

# %%
players
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
players
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
# aumentiamo il numero di colonne visibili
pd.set_option('display.max_columns', None)

# %%
players
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
players.columns.to_list()
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
# voglio vedere l'elenco di colonne
list_column = players.columns.to_list()
list_column
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %%
players['nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Slovenia', 'Belgium',
#        'Germany', 'Netherlands', 'Croatia', 'Egypt', 'France', 'Senegal',
#        'England', 'Spain', 'Italy', 'Uruguay', 'Poland', 'Denmark',
#        'Gabon', 'Korea Republic', 'Costa Rica', 'Slovakia',
#        'Bosnia Herzegovina', 'Serbia', 'Scotland', 'Hungary',
#        'Switzerland', 'Greece', 'Austria', 'Morocco', 'Sweden', 'Wales',
#        'Colombia', 'Czech Republic', 'Chile', 'Algeria', 'Ivory Coast',
#        'Togo', 'Norway', 'Mexico', 'Iceland', 'Finland', 'Jamaica',
#        'Albania', 'Guinea', 'Cameroon', 'Ghana', 'Montenegro', 'Ukraine',
#        'Russia', 'DR Congo', 'Central African Rep.', 'Venezuela',
#        'Nigeria', 'Armenia', 'Israel', 'Ecuador', 'Paraguay', 'Australia',
#        'Turkey', 'Romania', 'Japan', 'Mali', 'United States', 'Kosovo',
#        'Dominican Republic', 'Tanzania', 'China PR', 'Northern Ireland',
# ...

# %%
# quante nazioni abbiamo ?
elenco_nazioni = players['nationality'].unique()
elenco_nazioni
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Slovenia', 'Belgium',
#        'Germany', 'Netherlands', 'Croatia', 'Egypt', 'France', 'Senegal',
#        'England', 'Spain', 'Italy', 'Uruguay', 'Poland', 'Denmark',
#        'Gabon', 'Korea Republic', 'Costa Rica', 'Slovakia',
#        'Bosnia Herzegovina', 'Serbia', 'Scotland', 'Hungary',
#        'Switzerland', 'Greece', 'Austria', 'Morocco', 'Sweden', 'Wales',
#        'Colombia', 'Czech Republic', 'Chile', 'Algeria', 'Ivory Coast',
#        'Togo', 'Norway', 'Mexico', 'Iceland', 'Finland', 'Jamaica',
#        'Albania', 'Guinea', 'Cameroon', 'Ghana', 'Montenegro', 'Ukraine',
#        'Russia', 'DR Congo', 'Central African Rep.', 'Venezuela',
#        'Nigeria', 'Armenia', 'Israel', 'Ecuador', 'Paraguay', 'Australia',
#        'Turkey', 'Romania', 'Japan', 'Mali', 'United States', 'Kosovo',
#        'Dominican Republic', 'Tanzania', 'China PR', 'Northern Ireland',
# ...

# %%
type(elenco_nazioni)
elenco_nazioni.shape
# Out:
# (162,)

# %%
# quante nazioni sono (abbiamo un ndarray)
elenco_nazioni.shape
# Out:
# (162,)

# %%
players['nationality'].value_counts()
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
# quanti giocatori abbiamo per ogni nazione?
giocatori_nazione = players['nationality'].value_counts()
giocatori_nazione
# Out:
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: nationality, Length: 162, dtype: int64

# %%
giocatori_nazione[0:40].plot.bar()
# Out:
# <AxesSubplot: >

# %%
giocatori_nazione[0:20].plot.bar()
# Out:
# <AxesSubplot: >

# %%
giocatori_nazione.plot.pie()
# Out:
# <AxesSubplot: ylabel='nationality'>

# %% [markdown]
# # ORA PROVA TU:
# - Stampa un diagramma a barre che mette in evidenza il numero di ogni giocatore per ogni età (sulle ascisse le età e sulle ordinate il numero di giocatori
# - Stampa un diagramma Pie che mette in evidenza la distribuzione dei giocatori nelle sole squadre italiane

# %%
aa = players['age'].value_counts()
aa.plot.bar()
# Out:
# <AxesSubplot: >

# %%
a1 = players[players['nationality']=='Italy']
a2 = a1['club'].value_counts()
a2.plot.pie()
# Out:
# <AxesSubplot: ylabel='club'>

# %%
players.loc[0:10,'dob':'club']
# Out:
#            dob  height_cm  weight_kg  nationality                 club
# 0   1987-06-24        170         72    Argentina         FC Barcelona
# 1   1985-02-05        187         83     Portugal             Juventus
# 2   1992-02-05        175         68       Brazil  Paris Saint-Germain
# 3   1993-01-07        188         87     Slovenia      Atlético Madrid
# 4   1991-01-07        175         74      Belgium          Real Madrid
# 5   1991-06-28        181         70      Belgium      Manchester City
# 6   1992-04-30        187         85      Germany         FC Barcelona
# 7   1991-07-08        193         92  Netherlands            Liverpool
# 8   1985-09-09        172         66      Croatia          Real Madrid
# 9   1992-06-15        175         71        Egypt            Liverpool
# 10  1998-12-20        178         73       France  Paris Saint-Germain

# %%
players
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %% [markdown]
# Proviamo a creare una tabella **PIVOT**
#
# Una tabella pivot è uno strumento analitico e di reporting necessario alla creazione di tabelle riassuntive. Uno dei fini principali di queste tabelle è l'organizzazione di dati, tramite una scelta opportuna dei campi e degli elementi che devono comporla
#
# In Pandas possiamo usare il comando **pd.pivot_tables()**

# %%
pd.pivot_table(players, index=['nationality','short_name'], values=['age'])

# %%
# proviamo ad organizzare una tabella con dei raggruppamenti.
# creiamo un indice utilizzando nationality e short name. Nelle rispettive celle inseriamo 
# come valori le age
pd.pivot_table(players, index=['nationality','short_name'], values=['age'])
# Out:
#                            age
# nationality short_name
# Afghanistan H. Amin       27.0
#             N. Husin      22.0
# Albania     A. Abrashi    29.0
#             A. Ajdarević  29.0
#             A. Mehmeti    29.0
# ...                        ...
# Zimbabwe    M. Rusike     29.0
#             T. Darikwa    27.0
#             T. Hadebe     23.0
#             T. Kadewere   23.0
#             W. Katsande   33.0
#
# [17820 rows x 1 columns]

# %% [markdown]
# # Vediamo nel dettaglio il comando pivot_table
# <img src="fig/pivot-tables.png">

# %%
pd.pivot_table(players, index=['nationality', 'short_name'], values=['age', 'wage_eur'])

# %%
# proviamo ad aggiungere anche il valore della retribuzione (wage_eur)

pd.pivot_table(players, index=['nationality','short_name'], values=['age','wage_eur'])
# Out:
#                            age  wage_eur
# nationality short_name
# Afghanistan H. Amin       27.0    1000.0
#             N. Husin      22.0    2000.0
# Albania     A. Abrashi    29.0   15000.0
#             A. Ajdarević  29.0    4000.0
#             A. Mehmeti    29.0    1000.0
# ...                        ...       ...
# Zimbabwe    M. Rusike     29.0    2000.0
#             T. Darikwa    27.0   24000.0
#             T. Hadebe     23.0    4000.0
#             T. Kadewere   23.0    5000.0
#             W. Katsande   33.0    1000.0
#
# [17820 rows x 2 columns]

# %%
pd.pivot_table(players, index['nationality'], values['age'], aggfun)

# %%
# proviamo a:
# - raggruppiamo per nazione
# - volgio stampare nelle celle le età medie per nazioni

pd.pivot_table(players, index=['nationality'], values=['age'], aggfunc=[np.mean])
# Out:
#                         mean
#                          age
# nationality
# Afghanistan        24.500000
# Albania            24.813953
# Algeria            26.840000
# Angola             26.000000
# Antigua & Barbuda  22.857143
# ...                      ...
# Venezuela          24.696970
# Vietnam            24.000000
# Wales              24.897436
# Zambia             23.400000
# Zimbabwe           26.000000
#
# [162 rows x 1 columns]

# %%
pd.pivot_table(players, index=['nationality'], values=['age'], aggfunc=[np.mean, np.max, np.min, np.sum)])

# %%
# proviamo a:
# - raggruppiamo per nazione
# - volgio stampare nelle celle le età medie per nazioni, l'eta massima, l'età minima 
# e la somma delle età

pd.pivot_table(players, index=['nationality'], values=['age'], aggfunc=[np.mean, np.max,
                np.min, np.sum])
# Out:
#                         mean amax amin   sum
#                          age  age  age   age
# nationality
# Afghanistan        24.500000   27   22    49
# Albania            24.813953   33   17  1067
# Algeria            26.840000   33   18  1342
# Angola             26.000000   35   20   416
# Antigua & Barbuda  22.857143   28   18   160
# ...                      ...  ...  ...   ...
# Venezuela          24.696970   33   18  1630
# Vietnam            24.000000   24   24    24
# Wales              24.897436   35   17  2913
# Zambia             23.400000   30   19   234
# Zimbabwe           26.000000   33   21   312
#
# [162 rows x 4 columns]

# %%
# proviamo ad estrarre i valori per l'Italia
pivot = pd.pivot_table(players, index=['nationality'], values=['age'], aggfunc=[np.mean, np.max,
                np.min, np.sum])
pivot.loc['Italy']

# %%
pivot.loc['Italy']
# Out:
# mean  age       25.923497
# amax  age       41.000000
# amin  age       16.000000
# sum   age    18976.000000
# Name: Italy, dtype: float64

# %%
# Anche in questo caso posso produrre grafici

# %%
pivot2 = pd.pivot_table(players, index=['nationality'], values=['age'])
pivot2
# Out:
#                          age
# nationality
# Afghanistan        24.500000
# Albania            24.813953
# Algeria            26.840000
# Angola             26.000000
# Antigua & Barbuda  22.857143
# ...                      ...
# Venezuela          24.696970
# Vietnam            24.000000
# Wales              24.897436
# Zambia             23.400000
# Zimbabwe           26.000000
#
# [162 rows x 1 columns]

# %%
# ordiniamo
pivot2 = pivot2.sort_values('age')
pivot2
# Out:
#                            age
# nationality
# Indonesia            18.000000
# Rwanda               22.000000
# Niger                22.000000
# Antigua & Barbuda    22.857143
# Burkina Faso         23.187500
# ...                        ...
# São Tomé & Príncipe  32.000000
# Gibraltar            33.000000
# Ethiopia             33.000000
# Eritrea              34.000000
# Jordan               37.000000
#
# [162 rows x 1 columns]

# %%
# proviamo a stampare per ogni nazione il valore delle età
pivot2.plot.bar()
# Out:
# <AxesSubplot: xlabel='nationality'>

# %%
pivot2
# Out:
#                            age
# nationality
# Indonesia            18.000000
# Rwanda               22.000000
# Niger                22.000000
# Antigua & Barbuda    22.857143
# Burkina Faso         23.187500
# ...                        ...
# São Tomé & Príncipe  32.000000
# Gibraltar            33.000000
# Ethiopia             33.000000
# Eritrea              34.000000
# Jordan               37.000000
#
# [162 rows x 1 columns]

# %%
pivot2.plot.hist(bins=100)

# %% [markdown]
# # proviamo con un istogramma

# %%
# stampiamo ora per ogni età quanti giocatori hanno quell'età
pivot2.plot.hist(bins=100)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
pd.pivot_table(players, index=['nationality'], values['age'], columns=['preferred_foot']())

# %%
# Infine posso anche creare un ulteriore raggruppamento sulle colonne
pivot =pd.pivot_table(players, index=['nationality'], values=['age'], columns=['preferred_foot'],\
               aggfunc=[np.mean, np.max, np.min])

# %%
pivot
# Out:
#                         mean             amax        amin
#                          age              age         age
# preferred_foot          Left      Right  Left Right  Left Right
# nationality
# Afghanistan        27.000000  22.000000  27.0  22.0  27.0  22.0
# Albania            25.636364  24.531250  33.0  33.0  17.0  19.0
# Algeria            24.928571  27.583333  31.0  33.0  18.0  22.0
# Angola             24.000000  26.909091  27.0  35.0  20.0  20.0
# Antigua & Barbuda  26.000000  22.333333  26.0  28.0  26.0  18.0
# ...                      ...        ...   ...   ...   ...   ...
# Venezuela          25.250000  24.620690  33.0  33.0  19.0  18.0
# Vietnam                  NaN  24.000000   NaN  24.0   NaN  24.0
# Wales              25.160000  24.826087  32.0  35.0  20.0  17.0
# Zambia             21.000000  23.666667  21.0  30.0  21.0  19.0
# Zimbabwe           27.000000  25.666667  33.0  33.0  23.0  21.0
#
# [162 rows x 6 columns]

# %% [markdown]
# ## ORA PROVA TU
# - 1) CREA UNA TABELLA PIVOT CON QUESTE CARATTERISTICHE:
#     - Come indice: club di appartenenza
#     - Come valori: stipendio medio

# %%
#pd.pivot_table(players, index=['club'], values=['wage_eur'])

# %% [markdown]
# ## ORA PROVA TU
#
# - 2) CREA UNA TABELLA PIVOT CON QUESTE CARATTERISTICHE:
#     - Come indice: nazione, club di appartenenza
#     - Come valori: stipendio totale pagato a tutti i giocatori
#     - plotta con un bar i primi 25 club per spesa totale

# %%
table2 = pd.pivot_table(players, index=['club'], values=['wage_eur'], \
                        aggfunc=[np.sum])

# %%
# per ordinare la tabella
#table2 = table2.sort_values(by=('sum', 'wage_eur'), ascending=False)
#table2.iloc[0:11,:]

# %%
#table2.iloc[0:25,:].plot.bar()

# %%
pivot
# Out:
#                         mean             amax        amin
#                          age              age         age
# preferred_foot          Left      Right  Left Right  Left Right
# nationality
# Afghanistan        27.000000  22.000000  27.0  22.0  27.0  22.0
# Albania            25.636364  24.531250  33.0  33.0  17.0  19.0
# Algeria            24.928571  27.583333  31.0  33.0  18.0  22.0
# Angola             24.000000  26.909091  27.0  35.0  20.0  20.0
# Antigua & Barbuda  26.000000  22.333333  26.0  28.0  26.0  18.0
# ...                      ...        ...   ...   ...   ...   ...
# Venezuela          25.250000  24.620690  33.0  33.0  19.0  18.0
# Vietnam                  NaN  24.000000   NaN  24.0   NaN  24.0
# Wales              25.160000  24.826087  32.0  35.0  20.0  17.0
# Zambia             21.000000  23.666667  21.0  30.0  21.0  19.0
# Zimbabwe           27.000000  25.666667  33.0  33.0  23.0  21.0
#
# [162 rows x 6 columns]

# %% [markdown]
# PROVIAMO A ESPORTARE LA TABELLA PIVOT IN UN FOGLIO EXCEL

# %%
pivot.to_excel('tabella_pivot.xlsx')

# %% [markdown]
# # ESERCIZIO
# Sono un manager di successo e sono stato assunto dalla A.C. Roma nell'ambito di un progetto di rinnovamento societario finalizzato a portare la squadra a vincere lo scudetto nei prossimi 4 anni.
#
# La società mi ha assegnato 125.000.000 di euro da investire nell'acquisto di 5 calciatori.
# Nello specifico tre difensori, un centrocampista e due attaccanti.
#
# La società vuole investire nei giovani e quindi richiede che gli atleti abbiano un massimo di 23 anni.
#
# Il mio compito è quello di selezionare le migliori promesse sulla base dei dati in mio possesso.
#
# Come faccio a selezionare i giocatori più interessanti?
#
# Innanzitutto osserviamo i dati a disposizione

# %%
list_column
# Out:
# ['sofifa_id',
#  'player_url',
#  'short_name',
#  'long_name',
#  'age',
#  'dob',
#  'height_cm',
#  'weight_kg',
#  'nationality',
#  'club',
#  'overall',
#  'potential',
#  'value_eur',
#  'wage_eur',
#  'player_positions',
#  'preferred_foot',
#  'international_reputation',
#  'weak_foot',
#  'skill_moves',
#  'work_rate',
#  'body_type',
#  'real_face',
#  'release_clause_eur',
#  'player_tags',
#  'team_position',
#  'team_jersey_number',
#  'loaned_from',
#  'joined',
#  'contract_valid_until',
#  'nation_position',
#  'nation_jersey_number',
#  'pace',
#  'shooting',
#  'passing',
#  'dribbling',
#  'defending',
#  'physic',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_reflexes',
#  'gk_speed',
#  'gk_positioning',
#  'player_traits',
#  'attacking_crossing',
#  'attacking_finishing',
#  'attacking_heading_accuracy',
#  'attacking_short_passing',
#  'attacking_volleys',
#  'skill_dribbling',
#  'skill_curve',
#  'skill_fk_accuracy',
#  'skill_long_passing',
# ...

# %% [markdown]
# Sembrano interessanti 'overall', 'potential', 'value_eur', 'wage_eur',  'international_reputation','contract_valid_until',
#
# ma ci sono anche molti attributi specifici quali 'shooting', 'defencing',  'mentality_vision' etc...
#
# come mi posso muovere?

# %% [markdown]
# Intanto proviamo ad estrarre il potenziale e il valore attuale in euro

# %%
potential=players[['short_name', 'potential','value_eur']]

# %%
potential = players[['short_name','potential','value_eur']]
potential
# Out:
#               short_name  potential  value_eur
# 0               L. Messi         94   95500000
# 1      Cristiano Ronaldo         93   58500000
# 2              Neymar Jr         92  105500000
# 3               J. Oblak         93   77500000
# 4              E. Hazard         91   90000000
# ...                  ...        ...        ...
# 18273         Shao Shuai         56      40000
# 18274       Xiao Mingjie         56      40000
# 18275          Zhang Wei         56      40000
# 18276       Wang Haijian         54      40000
# 18277         Pan Ximing         51      40000
#
# [18278 rows x 3 columns]

# %%
potential.sort_values('potential', ascending=False)
# Out:
#               short_name  potential  value_eur
# 10             K. Mbappé         95   93500000
# 0               L. Messi         94   95500000
# 6          M. ter Stegen         93   67500000
# 73            M. de Ligt         93   50000000
# 1      Cristiano Ronaldo         93   58500000
# ...                  ...        ...        ...
# 18166          Sun Qibin         51      20000
# 18167          Z. Alkurt         50      30000
# 18168       R. Hernández         50      30000
# 18234       Zhang Junzhe         49      30000
# 18233          Zhou Ting         49          0
#
# [18278 rows x 3 columns]

# %%
# proviamo ad ordinare per potenziale
potential.sort_values('potential', ascending=False)
# Out:
#               short_name  potential  value_eur
# 10             K. Mbappé         95   93500000
# 0               L. Messi         94   95500000
# 6          M. ter Stegen         93   67500000
# 73            M. de Ligt         93   50000000
# 1      Cristiano Ronaldo         93   58500000
# ...                  ...        ...        ...
# 18166          Sun Qibin         51      20000
# 18167          Z. Alkurt         50      30000
# 18168       R. Hernández         50      30000
# 18234       Zhang Junzhe         49      30000
# 18233          Zhou Ting         49          0
#
# [18278 rows x 3 columns]

# %%
# proviamo ad ordinare per valore attuale
potential.sort_values('value_eur', ascending=False)
# Out:
#          short_name  potential  value_eur
# 2         Neymar Jr         92  105500000
# 0          L. Messi         94   95500000
# 10        K. Mbappé         95   93500000
# 5      K. De Bruyne         91   90000000
# 4         E. Hazard         91   90000000
# ...             ...        ...        ...
# 5905       N. Dunga         75          0
# 6013      C. Comara         73          0
# 3092  A. Gunnarsson         73          0
# 3053  F. Kudryashov         73          0
# 4670     A. Chipciu         71          0
#
# [18278 rows x 3 columns]

# %%
# Potrei provare con una tabella pivot ma non è molto chiara
work2= pd.pivot_table(potential, index=['potential','short_name'], values=['value_eur'])
work2.iloc[-20:,]
# Out:
#                                value_eur
# potential short_name
# 91        F. de Jong          52000000.0
#           H. Kane             83000000.0
#           K. De Bruyne        90000000.0
#           K. Koulibaly        67500000.0
#           P. Pogba            72500000.0
#           V. van Dijk         78000000.0
# 92        G. Donnarumma       41500000.0
#           J. Sancho           44500000.0
#           K. Havertz          46000000.0
#           L. Sané             61000000.0
#           Neymar Jr          105500000.0
#           P. Dybala           76500000.0
#           Vinícius Jr.        22500000.0
# 93        Cristiano Ronaldo   58500000.0
#           J. Oblak            77500000.0
#           João Félix          28000000.0
#           M. de Ligt          50000000.0
#           M. ter Stegen       67500000.0
# 94        L. Messi            95500000.0
# 95        K. Mbappé           93500000.0

# %%
# proviamo con uno scatter plot
# plottiamo sulle ascisse il potenziale e sull'ordinata il valore
potential.plot.scatter('potential','value_eur')
# Out:
# /home/giando/anaconda3/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <AxesSubplot: xlabel='potential', ylabel='value_eur'>

# %% [markdown]
# Provo a filtrare il mio dataset

# %%
pot_filter = player['potential']

# %%
pot_filter = ((players['potential']>80)&(players['potential']<100))
value_filter = ((players['value_eur']>0)&(players['value_eur']<50000000))
age_filter = ((players['age']>0)&(players['age']<25))
total_filter=pot_filter&value_filter&age_filter

# %%
new_players = players[total_filter]
new_players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1041 entries, 61 to 16717
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(16), int64(45), object(43)
# memory usage: 853.9+ KB

# %%
new_players
# Out:
#        sofifa_id                                         player_url  \
# 61        212622  https://sofifa.com/player/212622/joshua-kimmic...
# 74        230621  https://sofifa.com/player/230621/gianluigi-don...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
# 79        231866  https://sofifa.com/player/231866/rodrigo-herna...
# 80        208421  https://sofifa.com/player/208421/saul-niguez-e...
# ...          ...                                                ...
# 15330     242119  https://sofifa.com/player/242119/xavier-amaech...
# 15331     245907  https://sofifa.com/player/245907/jamie-bowden/...
# 15872     251752  https://sofifa.com/player/251752/lucas-chevali...
# 15873     252276  https://sofifa.com/player/252276/raul-prada-lo...
# 16717     252072  https://sofifa.com/player/252072/santiago-ramo...
#
#            short_name                   long_name  age         dob  height_cm  \
# ...

# %% [markdown]
# Cerchiamo ora i difensori

# %% [markdown]
# LEGENDA COLONNA **player_positions
# What are the FIFA positions?
#
# Check out the complete list of all FIFA positions now:
#
# Goalkeeper (GOAL / GK)
#
# The Goalkeeper, represented by the acronym GOL (or GK in English – Goalkeeper), is one of the most important positions in the game.
#
# Whether in career mode or playing online matches in Ultimate Team, it is essential that you always have two goalkeepers at your disposal: one on the field and the other on the bench.
#
# That’s because we know that anything can happen within FIFA matches. So, in case your goalkeeper gets injured or ends up getting a red card, it’s important that you have another one on the bench to replace him.
#
# Centre-Back (ZAG ​​/ CB)
#
# Defenders, in turn, represented by the acronym ZAG (CB in English – Central Back), form the most important part of your defense on the field.
#
# It’s interesting that you have another one on the bench in case something happens to one of those on the field, especially if you play with a lineup with two defenders.
#
# An alternative is to have two full-backs on the bench, as many players in that position can also act as full-backs without losing overall points.
#
# Right Back (LD / RB)
#
# The right side, represented by the acronym LD (RB in English – Right Back), is the one who takes care of the defense of the right side of the field.
#
# The vast majority of players who play in this position can also be selected to play in the left-back position.
#
# Some of these players can also be cast in games as defenders or as left midfielders or right midfielders, as they perform well both in attack and defense.
#
# In FIFA 21, full-backs who can also play as a right midfielder or left midfielder were represented by the acronym ADD.
#
# However, in FIFA 22 this acronym no longer exists. In any case, check the SoFIFA website. It is the best option to know which players can be selected in these positions.
#
# Left Back (LE / LB)
#
# The left side, represented by the acronym LE (LB in English – Left Back), is the player responsible for defending the left side of the field.
#
# Like right-backs, left-backs can also be cast as right-backs if the need arises.
#
# Some of these players, as well as the right backs, can also be called as defenders or as left or right midfielders.
#
# In any case, just follow the tip we gave in the previous topic and stay tuned to SoFIFA.
#
# Central Defensive Midfielder (VOL / CDM)
#
# The defensive midfielder, represented by the acronym VOL (CDM in English – Central Defensive Midfielder) acts as a more defensive midfielder, but in the end, ends up acting as a handyman in the midfield.
#
# He can be responsible for putting together interesting plays and passing to the other midfield players so that the ball reaches the attacker’s feet.
#
# Central Midfielder (MC/CM)
#
# The midfielder, represented by the acronym MC (CM in English – Central Midfielder) is responsible for setting up the plays.
#
# In very difficult cases, you can put a right midfielder, left midfielder or attacking midfielder to play in this position if necessary.
#
# Right Midfielder (MD/RM)
#
# The Right Midfielder, represented by the acronym MD (RM in English – Right Midfielder) is a slightly more versatile player, who can be scaled in place of the wingers of your team.
#
# He can be replaced by the left midfielder without major problems. In some cases, he may lose some points, but there are players who do well in both positions.
#
# He’s a more attacking midfielder type, but he doesn’t do as well in the more central positions of the field.
#
# If necessary, he can be replaced by a winger or an attacking midfielder.
#
# Left Midfielder (ME/LM)
#
# The left midfielder, represented by the acronym ME (LM in English – Left Midfielder) is a player who is in the offensive part on the left.
#
# Like the right midfielder, he can also play in the opposite position, and there are several players who are versatile and can play on both sides of the field.
#
# Like the right midfielder, these players just don’t play very well in the most central offensive position (although there are exceptions, such as Jadon Sancho) and can be replaced by players who act as wingers.
#
# Central Attacking Midfielder (MEI / CAM)
#
# The Offensive Midfielder, represented by the acronym MEI (CAM in English – Central Attacking Midfielder), in turn, is a type of midfielder who plays more advanced, in a more suitable position for the attack.
#
# They are the most versatile players in the game, as they can replace left midfielders, right midfielders, left wingers, right wingers and centre forwards.
#
# Left Wing (PE / LW)
#
# The left winger, represented by the acronym PE (LW in English – Left Wing) is an attacking player who plays on the left. This is the case of Neymar and Vinícius Jr, for example, and they are some of the fastest players in the game.
#
# Some of these players are more versatile and can play well on both sides of the field, like Ansu Fati, for example, while others can also play as attacking midfielders or centre forwards.
#
# Right Wing (PD / RW)
#
# The right winger, represented by the acronym PD (RW in English – Right Wing) on ​​the other hand, is an attacking player who prioritizes the advance on the right side. This is the case of Lionel Messi and Federico Chiesa, for example.
#
# Like left wingers, right wingers tend to be very fast players with great dribbling skills.
#
# Many of them also play well in the position of attacking midfielders or centre forwards and some players play well on both sides of the field.
#
# Centre Forward (SA/CF)
#
# The centre forward, represented by the acronym SA (CF – Center Forward), in turn, is a player who is almost an attacking midfielder, but who is even more advanced on the pitch.
#
# This is the case of players like João Félix, from Atlético de Madrid, or Karim Benzema, from Real Madrid.
#
# These players are usually quite fast and are great to play in a false 9 formation.
#
# Striker (ATA / ST)
#
# posições fifa atacante
# Finally, we have the strikers, represented by the acronym ATA (ST in English – Striker) is the most important position of the attack.
#
# Some examples of players who play in this position are Kylian Mbappe, Erling Haaland, Robert Lewandowski and Cristiano Ronaldo.
#
# They are usually fast players and those who have a good ability to kick the ball correctly into the goal.
#
# Most players in this position cannot play in other positions, but there are versatile options, such as Kylian Mbappe, who can be placed as a left or right winger in your team without major problems.

# %% [markdown]
# I difensori sono RB, CB, LB

# %%
rb_filter=new_players['player_positions'].str.contains('RB')
rc_filter=new_players['player_positions'].str.contains('RL')
rl_filter=new_players['player_positions'].str.contains('RC')
defender_filter=rb_filter | rc_filter | rl_filter

# %%
defender = new_players[defender_filter]
defender
# Out:
#        sofifa_id                                         player_url  \
# 61        212622  https://sofifa.com/player/212622/joshua-kimmic...
# 160       231281  https://sofifa.com/player/231281/trent-alexand...
# 332       240130  https://sofifa.com/player/240130/eder-gabriel-...
# 413       225100  https://sofifa.com/player/225100/joe-gomez/20/...
# 428       203747  https://sofifa.com/player/203747/hector-beller...
# ...          ...                                                ...
# 12177     242752  https://sofifa.com/player/242752/nathan-fergus...
# 13104     246763  https://sofifa.com/player/246763/ki-jana-hoeve...
# 13106     247876  https://sofifa.com/player/247876/robbe-quiryne...
# 13120     242334  https://sofifa.com/player/242334/jaylin-lindse...
# 13979     245153  https://sofifa.com/player/245153/nathan-wood/2...
#
#                 short_name               long_name  age         dob  \
# 61              J. Kimmich          Joshua Kimmich   24  1995-02-08
# ...

# %% [markdown]
# Un'altra colonna importante è 'release_clause_eur' perchè per poter acquistare il calciatore devo pagare una clausola rescissoria alla società di appartenenza e questo deve essere compatibile con il mio budget.

# %% [markdown]
# Ora ne abbiamo 86. Dobbiamo selezionarne 3
# Potremmo utilizzare la colonna overall, ma voglio provare a costruire una mia METRICA
#
# Una **METRICA** è una funzione che ci permette di assegnare un valore numerico ad ogni calciatore sulla base di criteri predefiniti
#
# Noto che ho altre informazioni nelle colonne che mi dicono **L'ABILITA'** del calciatore
#
# shooting,passing,dribbling,defending,physic
#
# Potrei usare queste colonne per avere un unico valore che rappresenta **L'ABILITA' COMPLESSIVA** del calciatore

# %% [markdown]
# Come posso scegliere questa METRICA?
# - Una prima scelta potrebbe essere LA FUNZIONE $metrica1=shooting+passing+dribbling+defending+physic$
# - Una seconda scelta potrebbe essere LA FUNZIONE
# $metrica2=shooting*passing*dribbling*defending*physic$
#
# La principale differenza tra la somma e il prodotto come metriche per la valutazione delle abilità dei calciatori sta nella modalità di aggregazione delle abilità.
#
# La **somma delle abilità** implica l'aggiunta dei valori di ciascuna abilità per ottenere un punteggio totale. Questo approccio tiene conto dell'importanza relativa di ciascuna abilità e non penalizza i calciatori che sono forti in alcune abilità ma deboli in altre. In questo modo, **la somma delle abilità può fornire una valutazione complessiva dell'efficacia del calciatore in campo**.
#
# D'altra parte, il **prodotto delle abilità** implica la moltiplicazione dei valori di ciascuna abilità per ottenere un punteggio totale. Questo approccio dà maggior peso alle abilità in cui il calciatore eccelle, e penalizza le abilità in cui è meno efficace. Di conseguenza, il **prodotto delle abilità potrebbe essere utile per identificare i calciatori che sono particolarmente forti in una specifica abilità**, ma potrebbe essere meno indicativo dell'efficacia complessiva del calciatore in campo.

# %% [markdown]
# Sono interessato ad un difensore che è completo è impiegabile in diversi ruoli quindi opto per la SOMMA

# %%
# levo un po' di colonne
new_defender=defender.loc[:,'short_name':'physic']

# %% [markdown]
# Poichè le abilità a mia disposizione sono
#
# shooting,passing,dribbling,defending, physic
#
# e a me interessano maggiormente per un difensore quelle di defending e physics, assegnerò un peso diverso alle singole abilità

# %%
new_defender
# Out:
#                 short_name               long_name  age         dob  \
# 61              J. Kimmich          Joshua Kimmich   24  1995-02-08
# 160    T. Alexander-Arnold  Trent Alexander-Arnold   20  1998-10-07
# 332           Éder Militão    Éder Gabriel Militão   21  1998-01-18
# 413               J. Gomez               Joe Gomez   22  1997-05-23
# 428        Héctor Bellerín  Héctor Bellerín Moruno   24  1995-03-19
# ...                    ...                     ...  ...         ...
# 12177          N. Ferguson         Nathan Ferguson   18  2000-10-06
# 13104            K. Hoever          Ki-Jana Hoever   17  2002-01-18
# 13106          R. Quirynen          Robbe Quirynen   17  2001-11-03
# 13120           J. Lindsey          Jaylin Lindsey   19  2000-03-27
# 13979              N. Wood             Nathan Wood   17  2002-05-31
#
#        height_cm  weight_kg    nationality                  club  overall  \
# 61           176         73        Germany     FC Bayern München       86
# ...

# %%
new_defender['Metrics1']=1.7*new_defender['defending'] \
+ 0.7*new_defender['shooting']+0.9*new_defender['passing'] \
+ 0.6*new_defender['dribbling']+1.3*new_defender['physic']

# %%
new_defender
# Out:
#                 short_name               long_name  age         dob  \
# 61              J. Kimmich          Joshua Kimmich   24  1995-02-08
# 160    T. Alexander-Arnold  Trent Alexander-Arnold   20  1998-10-07
# 332           Éder Militão    Éder Gabriel Militão   21  1998-01-18
# 413               J. Gomez               Joe Gomez   22  1997-05-23
# 428        Héctor Bellerín  Héctor Bellerín Moruno   24  1995-03-19
# ...                    ...                     ...  ...         ...
# 12177          N. Ferguson         Nathan Ferguson   18  2000-10-06
# 13104            K. Hoever          Ki-Jana Hoever   17  2002-01-18
# 13106          R. Quirynen          Robbe Quirynen   17  2001-11-03
# 13120           J. Lindsey          Jaylin Lindsey   19  2000-03-27
# 13979              N. Wood             Nathan Wood   17  2002-05-31
#
#        height_cm  weight_kg    nationality                  club  overall  \
# 61           176         73        Germany     FC Bayern München       86
# ...

# %%
new_defender.sort_values('Metrics1', ascending=False)
# Out:
#                 short_name                long_name  age         dob  \
# 61              J. Kimmich           Joshua Kimmich   24  1995-02-08
# 160    T. Alexander-Arnold   Trent Alexander-Arnold   20  1998-10-07
# 621              L. Dubois               Léo Dubois   24  1994-09-14
# 332           Éder Militão     Éder Gabriel Militão   21  1998-01-18
# 812            D. Dumfries          Denzel Dumfries   23  1996-04-18
# ...                    ...                      ...  ...         ...
# 13120           J. Lindsey           Jaylin Lindsey   19  2000-03-27
# 11044          Mateu Morey  Mateu Jaume Morey Bauzá   19  2000-03-02
# 13106          R. Quirynen           Robbe Quirynen   17  2001-11-03
# 12177          N. Ferguson          Nathan Ferguson   18  2000-10-06
# 13979              N. Wood              Nathan Wood   17  2002-05-31
#
#        height_cm  weight_kg    nationality                  club  overall  \
# ...

# %% [markdown]
# Devo considerare la clasuola rescissoria

# %%
clause_filter = (new_defender['release_clause_eur']<10000000)
new_defender= new_defender[clause_filter]

# %%
new_defender=new_defender.sort_values('Metrics1', ascending=False)

# %% [markdown]
# la mia scelta è per i primi tre

# %%
defender_last=new_defender.iloc[0:3,:]
defender_last
# Out:
#      short_name               long_name  age         dob  height_cm  \
# 4072   A. Tello            Andres Tello   22  1996-09-06        181
# 3337   K. Rüegg             Kevin Rüegg   20  1998-08-05        173
# 4059    Emerson  Emerson Leite De Souza   20  1999-01-14        181
#
#       weight_kg  nationality        club  overall  potential  value_eur  \
# 4072         80     Colombia   Benevento       71         81    3800000
# 3337         77  Switzerland   FC Zürich       72         82    4600000
# 4059         79       Brazil  Real Betis       71         83    3900000
#
#       wage_eur player_positions preferred_foot  international_reputation  \
# 4072      3000           CM, RB          Right                         1
# 3337      8000          RB, CDM          Right                         1
# 4059      9000               RB          Right                         1
#
#       weak_foot  skill_moves    work_rate body_type real_face  \
# ...

# %%
defender_last.shape
# Out:
# (29, 36)

# %% [markdown]
# Quanto mi costa?

# %%
tot_clause=defender_last['release_clause_eur'].sum()
tot_salary=defender_last['wage_eur'].sum()
tot_cost_defender=tot_clause+tot_salary
tot_cost_defender
# Out:
# 23220000.0

# %% [markdown]
# # ORA PROVA TU
# Completa l'esercizio e trova i centrocampisti e gli attaccanti
