# %% [markdown]
# # INTRODUCTION TO CLASSIFICATION

# %%
# !pip install pandas
 # !pip install seaborn
 # !pip install sklearn
 # !pip install statsmodels

# %%
# %load ../standard_import.txt
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn.linear_model as skl_lm
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, classification_report, precision_score
from sklearn import preprocessing


import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.discrete.discrete_model as smd

from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, roc_curve 
#import seaborn.apionly as sns
from sklearn.metrics import f1_score, precision_recall_fscore_support, roc_auc_score, auc, make_scorer

# %matplotlib inline
plt.style.use('seaborn-white')
# Out:
# /tmp/ipykernel_119249/3834255732.py:23: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ## the dataset is the DEFAULT dataset of the ISLR book. Chapter 4 pg 129.
# - we have 2 features: annual income and monthly credit card balances
# - we also have qualitative(categorical) variable Student (YES/NO) and default (YES/NO)
# - we are interested in predicting whether an individual will default on her/his credit card payment based on annual income and montly credit card balance

# %%
# let's load the data
df = pd.read_csv('Data/Default.csv')

# %%
# we have 10000 samples. about 400 KB of memory. Not too much
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10000 non-null  int64
#  1   default     10000 non-null  object
#  2   student     10000 non-null  object
#  3   balance     10000 non-null  float64
#  4   income      10000 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 390.8+ KB

# %%
# let's have a look
df.head(10)
# Out:
#    Unnamed: 0 default student      balance        income
# 0           1      No      No   729.526495  44361.625074
# 1           2      No     Yes   817.180407  12106.134700
# 2           3      No      No  1073.549164  31767.138947
# 3           4      No      No   529.250605  35704.493935
# 4           5      No      No   785.655883  38463.495879
# 5           6      No     Yes   919.588530   7491.558572
# 6           7      No      No   825.513331  24905.226578
# 7           8      No     Yes   808.667504  17600.451344
# 8           9      No      No  1161.057854  37468.529288
# 9          10      No      No     0.000000  29275.268293

# %%
df[df['balance']==0]
# Out:
#       Unnamed: 0 default student  balance        income  default2  student2
# 9             10      No      No      0.0  29275.268293         0         0
# 10            11      No     Yes      0.0  21871.073089         0         1
# 16            17      No      No      0.0  50265.312354         0         0
# 54            55      No      No      0.0  49956.580572         0         0
# 62            63      No      No      0.0  32481.540046         0         0
# ...          ...     ...     ...      ...           ...       ...       ...
# 9865        9866      No      No      0.0  43593.953603         0         0
# 9891        9892      No      No      0.0  43969.215100         0         0
# 9894        9895      No      No      0.0  34836.340699         0         0
# 9959        9960      No      No      0.0  53946.233652         0         0
# 9988        9989      No      No      0.0  41740.686597         0         0
#
# [499 rows x 7 columns]

# %%
len(df)
# Out:
# 10000

# %%
# we want to create the 2 classes both for default and for students

# Note: factorize() returns two objects: a label array (1 and 0) and an array with the unique values.
# We are only interested in the first object. 
# We create 2 more columns on our dataset with the "flags" 0 and 1 for Student-Non Student and Default- Non Default

df['default2'] = df.default.factorize()[0]
df['student2'] = df.student.factorize()[0]
df.head(3)
# Out:
#    Unnamed: 0 default student      balance        income  default2  student2
# 0           1      No      No   729.526495  44361.625074         0         0
# 1           2      No     Yes   817.180407  12106.134700         0         1
# 2           3      No      No  1073.549164  31767.138947         0         0

# %% [markdown]
# ## We want to visualize data first to have an understanding

# %%
df[df.default2 == 0]
# Out:
#       Unnamed: 0 default student      balance        income  default2  \
# 0              1      No      No   729.526495  44361.625074         0
# 1              2      No     Yes   817.180407  12106.134700         0
# 2              3      No      No  1073.549164  31767.138947         0
# 3              4      No      No   529.250605  35704.493935         0
# 4              5      No      No   785.655883  38463.495879         0
# ...          ...     ...     ...          ...           ...       ...
# 9995        9996      No      No   711.555020  52992.378914         0
# 9996        9997      No      No   757.962918  19660.721768         0
# 9997        9998      No      No   845.411989  58636.156984         0
# 9998        9999      No      No  1569.009053  36669.112365         0
# 9999       10000      No     Yes   200.922183  16862.952321         0
#
#       student2
# 0            0
# 1            1
# 2            0
# 3            0
# 4            0
# ...        ...
# ...

# %%
# Take a fraction of the samples where target value (default) is 'no'
df_no = df[df.default2 == 0].sample(frac=0.15)
# Take all samples  where target value is 'yes'
df_yes = df[df.default2 == 1]

# append the default YES to the end of the sample of DEFAULT NO
df_ = df_no.append(df_yes)
# Out:
# /tmp/ipykernel_119249/3476177543.py:7: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_ = df_no.append(df_yes)

# %%
df_.shape
# Out:
# (1783, 7)

# %%
df_.head(5)
# Out:
#       Unnamed: 0 default student      balance        income  default2  \
# 2482        2483      No      No   681.417623  26426.229206         0
# 3237        3238      No      No  1306.257568  29376.441375         0
# 5377        5378      No      No   702.159263  57468.404441         0
# 958          959      No      No   866.045923  44827.265879         0
# 8494        8495      No      No   603.020400  51229.788470         0
#
#       student2
# 2482         0
# 3237         0
# 5377         0
# 958          0
# 8494         0

# %%
# now let's plot the boxplots

fig = plt.figure(figsize=(12,5))
gs = mpl.gridspec.GridSpec(1, 4)
ax1 = plt.subplot(gs[0,:-2])
ax2 = plt.subplot(gs[0,-2])
ax3 = plt.subplot(gs[0,-1])

#Let's plot the dafault = YES
ax1.scatter(df_[df_.default == 'Yes'].balance, df_[df_.default == 'Yes'].income, s=40, c='orange', marker='+',
            linewidths=1, label="Defaulted")

#In the same plot ax1 we plot also the default=NO
ax1.scatter(df_[df_.default == 'No'].balance, df_[df_.default == 'No'].income, s=40, marker='o', linewidths='1',
            edgecolors='blue', facecolors='white', alpha=.3, label="Not Defaulted")
ax1.legend()


# we set the axes of ax1
ax1.set_ylim(ymin=0)
ax1.set_ylabel('Income')
ax1.set_xlim(xmin=-100)
ax1.set_xlabel('Balance')

# now we plot the boxplot on ax2 ax3
# we use all the sample for the boxplot
c_palette = {'No':'lightblue', 'Yes':'orange'}
sns.boxplot('default', 'balance', data=df, orient='v', ax=ax2, palette=c_palette)
sns.boxplot('default', 'income', data=df, orient='v', ax=ax3, palette=c_palette)
gs.tight_layout(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_119249/2277765236.py in <module>
#      26 # we use all the sample for the boxplot
#      27 c_palette = {'No':'lightblue', 'Yes':'orange'}
# ---> 28 sns.boxplot('default', 'balance', data=df, orient='v', ax=ax2, palette=c_palette)
#      29 sns.boxplot('default', 'income', data=df, orient='v', ax=ax3, palette=c_palette)
#      30 gs.tight_layout(plt.gcf())
#
# TypeError: boxplot() got multiple values for argument 'data'
# Error in callback <function _draw_all_if_interactive at 0x7f765acceb80> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in _draw_all_if_interactive()
#     117 def _draw_all_if_interactive():
# ...

# %% [markdown]
# FIGURE 4.1. The Default data set. Left: The annual incomes and monthly
# credit card balances of a number of individuals. The individuals who defaulted on
# their credit card payments are shown in orange, and those who did not are shown
# in blue. Center: Boxplots of balance as a function of default status. Right:
# Boxplots of income as a function of default status.

# %% [markdown]
# We can see that **Income** variable seems less important in determine the default while the **Balance** variable seems to have relationship with default

# %% [markdown]
# We want to find a way to CLASSIFY our input vector.
#
# Here we have 2 classes: $0$ - non default (BLUE) and $1$ - DEFAULT (ORANGE)
#
# # Decision Boundary
#
# Looking at our FEATURES SPACE we want to find a rule to assign an input vector $X = (BALANCE, INCOME)$ to a SPECIFIC class.
#
# Our rule should create a BOUNDARY in the FEATURES SPACE (space of samples) in order to define subsets of samples which correspond to specific classes. We say that our FEATURES SPACE is divided into DECISION REGIONS, whose boundaries are called DECISION BOUNDARY or DECISION SURFACES
#
# A first approch is to looking for LINEAR BOUNDARIES which are defined by means of LINEAR FUNCTIONS of the input vector $X$, hence a D-1 dimensional hyperplane of the D dimensional feature vectors space). If I can find this function, datasets are called LINEARLY SEPARABLE
#
# # Approaches
# In general we have 3 general approaches to solve a classification problems
#
# 1) constructing a DISCRIMINANT FUNCTION that DIRECTLY assign the input vector $X$ to a class. This is a NON PROBABILISTIC model
#
# 2) use PROBABILISTIC MODEL (so we can use the power of inference) and try to find the CONDITIONAL PROBABILITY DISTRIBUTION $P(Y=1|X)$ in an INFERENCE STAGE ($Y$ could be $0$ or $1$ as we consider only 2 class here) and then uses this distribution to make OPTIMAL DECISIONS (REMEMBER these 2 steps are ALWAYS SEPARATED).
#
# We have 2 different sub-approaches for point 2
#
# 2.1) Model $P(Y=1|X)$ DIRECTLY. We can identify a potential FORM of the function and PARAMETRIZE it. We can make an inference stage to determine unknown parameters fitting over our data. We can MAKE INFERENCE on accuracy of the parameters like in ordinary linear regression. Then we go to stage 2. Make decision and create the boundary. These are called DISCRIMINATIVE MODELS (e.g logistic regression)
#
# <br>
# 2.2) We apply a so called GENERATIVE APPROACH. We model the CLASS CONDITIONAL DENSITY $P(X|Y)$ together with a PRIOR PROBABILITY on $Y$, $P(Y)$. Then by means of the BAYS' THEOREM, find the POSTERIOR probabilities: $P(Y|X) = P(X|Y) * P(Y) / P(X)$.
# In this approach we FIRST MODEL THE CLASS CONDITIONAL DENSITY and then by means of a PRIORI ASSUMPION we calculate the posterior that we need. This is the reason why it is called GENERATIVE APPROACH. Some example are LINEAR DISCRIMINANT ANALYSIS or QUADRATIC DISCRIMINANT ANALYSIS

# %% [markdown]
# ## DISCRIMINANT FUNCTION (NON PROBABILISTIC)

# %% [markdown]
# Considering our example, I have 2 features $(Income,Balance)$ in a 2 DIMENSIONAL FEATURES SPACE, i.e. a PLANE.  My goal to find a LINE (dim-1 space) that will be my THE DECISION BOUNDARY and will splits the Features Space in 2 sub-spaces: one containing vectors which belong to CLASS 1 and one with vectors belong to to CLASS 2.
#
# Our input vector is $X = (BALANCE, INCOME)$
#
# I choose a PARAMETRIC function that is LINEAR:
#
# $\hat Y = \beta_0 + X* \bar \beta_1$
#
# TAKE CARE - **STEP 1**
#
# I will FIRST determine the parameters ($\beta_0$ and $\bar \beta_1$) FROM DATA by means of a train on my AVAILABLE data,
#
# THEN - **STEP 2**
#
# Based on $\hat Y$, I will define a DECISION RULE to assign features vectors $X=(Balance,Income)$ to CLASS1 OR CLASS2, i.e. we will partition the features space.
#
# In our example we have only 2 classes - DEFAULTED (1) and NOT DEFAULTED (0)
#
# The DECISION RULE will be:
#
# if $\hat Y(X) >= 0$, $X$ belong to class 1 (DEFAULTED),
#
# if  $\hat Y(X) < 0$ belong to class 0 (NON DEFAULTED)

# %% [markdown]
# My model is in the form $\hat Y = \beta_0 + X * \bar \beta_1$ where $X$ is a (10000,2) matrix of (BALANCE, INCOME) and $Y$ is a (10000,1) RESPONSE vector of values $0$ and $1$. $\bar \beta_1$ is a 2 dim vector and $\beta_0$ is a scalar.
#
# I will find parameters as always, minimizing over $\beta$'s the quantity $(Y - \hat Y)$

# %%
# We can use OLS to find parameters

model1 = smf.ols('default2 ~ balance + income', df)
est = model1.fit()
est.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
est.params
# Out:
# Intercept   -9.223968e-02
# balance      1.318050e-04
# income       4.604568e-07
# dtype: float64

# %% [markdown]
# Remember: this is NOT a probabilistic model. I USE OLS ONLY TO TO CALCULATE the values of the coefficient.

# %% [markdown]
# Now I have calculate my parameters FROM DATA.
#
# What can I do now with this function?
#
# I move ahead to step2: the DECISION STAGE. My RULE was $\hat Y >=0$ => CLASS 1 and $\hat Y <0$=> CLASS 0.
#
# The DECISION BOUNDARY corresponds to $\hat Y = 0$, so:
#
# $0 = \beta_0 + X* \bar \beta_1$
#
# $0= \beta_0 + Balance*\beta_1^1 + Income*\beta_1^2$
#
# so the boundary function $Income = f(Balance)$ will be:
#
# $Income = -(\beta_0 + Balance*\beta_1^1) / \beta_1^2$
#
# PLEASE ALSO NOTE THAT:
#
# $\hat Y >=0$   $=>$    $\beta_0 + Balance*\beta_1^1 + Income*\beta_1^2 > 0$ $=>$
#
# SO WHEN $Income > -(\beta_0 + Balance*\beta_1^1) / \beta_1^2$
#
# POINTS ARE CLASSIFIED TO BELONG TO CLASS 1

# %%
# I define a function to calculate Income = f(Balance)

def line1 (x):
    return (-est.params[0]-est.params[1]*x)/est.params[2]

# I choose to points of the boundary line to generate the line
x1=470
x2=710
y1 = line1(x1)
y2 = line1(x2)
print((x1,y1),(x2,y2))
# Out:
# (470, 65785.42860922066) (710, -2914.1599974430674)

# %%
# plot the boundary
fig = plt.figure(figsize=(25,10))
gs = mpl.gridspec.GridSpec(1, 4)
ax1 = plt.subplot(gs[0,:-2])

#Let's plot the dafault = YES
ax1.scatter(df_[df_.default == 'Yes'].balance, df_[df_.default == 'Yes'].income, s=40, c='orange', marker='+',
            linewidths=1)

#In the same plot ax1 we plot also the default=NO
ax1.scatter(df_[df_.default == 'No'].balance, df_[df_.default == 'No'].income, s=40, marker='o', linewidths='1',
            edgecolors='blue', facecolors='white', alpha=.3)

# Plot the BOUNDARY LINE
plt.plot([x1,x2],[y1,y2], c='red')

# we set the axes of ax1
ax1.set_ylim(ymin=0)
ax1.set_ylabel('Income')
ax1.set_xlim(xmin=-100)
ax1.set_xlabel('Balance')
#ax1.text(23, 222, 'unicode: Institut für Festkörperphysik')
ax1.text(1513, 60000, 'DEFAULTED- CLASS 1', style='italic',
        bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 10})
ax1.text(30, 5000, 'NON DEFAULTED - CLASS 0', style='italic',
        bbox={'facecolor': 'green', 'alpha': 0.5, 'pad': 10})
ax1.text(500, 65000, 'DECISION BOUNDARY', style='italic',
        bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})
# Out:
# Text(500, 65000, 'DECISION BOUNDARY')

# %%
# intersection is at 700 
line1(700)
# Out:
# -51.67713883207211

# %% [markdown]
# We can see the red line splits the feature space in 2 subsets. On the left we have the input vectors which belong to class 0 and on the right to class 1

# %% [markdown]
# Did I make a nice Job? How can I measure the ERROR, the PERFORMANCE of my classifier?
# We use the concept of CONFUSION MATRIX

# %% [markdown]
# <img src="figures/confmat.png">
#
# **Sensitivity** (also called the true positive rate, the RECALL, or probability of detection in some fields) measures the proportion of actual positives that are correctly identified as such (e.g., the percentage of sick people who are correctly identified as having the condition).
#
# **Specificity** (also called the true negative rate) measures the proportion of actual negatives that are correctly identified as such (e.g., the percentage of healthy people who are correctly identified as not having the condition).
#
# ## here a summary
#
# <img src="figures/conf1.png" alt="Drawing" style="width: 400px;">
# <img src="figures/conf2.png" alt="Drawing" style="width: 400px;">
# <img src="figures/conf3.png" alt="Drawing" style="width: 400px;">

# %% [markdown]
# Let's apply this concept on our TRAINING SET (take care we should apply on a TEST SET)

# %% [markdown]
# FIRST A MAKE THE PREDICTION STAGE
#
# we use the fitted parameters to calculate the predictions of our features for which we already have the TRUE values. So we can understand how our predictor is well.
#
# Remember that this is a TRAINING TEST so we expect very nice results because our predictors has been fitted on that data

# %%
est.params
# Out:
# Intercept   -9.223968e-02
# balance      1.318050e-04
# income       4.604568e-07
# dtype: float64

# %%
# calculate the prediction
y_ptrain = est.params[0] + est.params[1] * df.balance.values + est.params[2] * df.income.values

# %%
# Let's have a look at the distribution of predicted values
plt.hist(y_ptrain, bins=500);

# %% [markdown]
# NOW I APPLY MY DECISION RULE$\hat Y >= 0$ MEANS CLASS 1 , OTHERWISE CLASS 0(v) ON THE PREDICTED VECTOR
#
# ..QUESTION: IS IT THE BEST DECISION ?? (WE THINK ON IT LATER..)

# %%
# create a baseline vector of predicted classes
y_target = np.zeros(len(y_ptrain))
# create the vector of PREDICTED CLASSES BASED ON MY DECISION RULE
for i in range(len(y_ptrain)):
    if y_ptrain[i] >= 0:
        y_target[i] = 1

# %%
# print the classes
y_target
# Out:
# array([1., 1., 1., ..., 1., 1., 0.])

# %%
#extract the TRUE classes
y = df.default2.values

#Generate confusion matrixes and print main indicators
print('\n'.join(['\t'.join([str(cell) for cell in row]) for row in [['TN', 'FP'],['FN','TP']]]))

#generate confusion matrixes
cm_train = confusion_matrix(y,y_target)

hm = sns.heatmap(cm_train,cbar=True,annot=True,square=True,fmt='d',annot_kws={'size': 12},cmap = sns.diverging_palette(220, 10, as_cmap=True))
plt.title('Training set CONFUSION MATRIX', fontsize=14)

plt.tight_layout()
plt.show()

print('Precision = {0:5.4f}'.format(precision_score(y,y_target)))
print('Recall= {0:5.4f}'.format(recall_score(y,y_target)))
print('F1-score= {0:5.4f}'.format(f1_score(y,y_target)))
print('Accuracy = {0:5.4f}'.format(accuracy_score(y,y_target)))
print('AUC = {0:5.4f}'.format(roc_auc_score(y,y_target)))
# Out:
# TN	FP
# FN	TP
# Precision = 0.0486
# Recall= 1.0000
# F1-score= 0.0927
# Accuracy = 0.3478
# AUC = 0.6627

# %% [markdown]
# Our C Matrix shows a lot of FALSE POSITIVE which means that our predictors classified as defaulted a lot of TRUE-NON -defaulted samples classified defaulted- It is showed with a very lowe PRECISION.
#
# We obtained VERY BAD results even if we are considering training data.
#
# WHAT CAN WE DO?

# %% [markdown]
# ## PROBABILISTIC APPROACH

# %% [markdown]
# Now we want to use a probabilistic model TO MAKE PREDICTION
#
# This means that independently of the decision rule I will find a predictor that will predict based on PROBABILITY and not based on deterministic numbers like previous example.
#
# Can we use a linear regression? In general no. We have a discrete variable Y and we can encode Y as 1,2,3,4.... but in general the results are coding dependent and leads to different prediction results
#
# In case of a BINARY qualitative response Y, we can use dummy variable approach coding Y as 0 or 1, fit a linear regression.
#
# It can be shown that in the probabilistic model $\hat Y = X * \bar \beta = E(Y|X) = Pr(Y=1|X)$
#
# A DECISION RULE in this case could be for example $\hat Y >= 0.5$ for one class and $\hat Y < 0.5$ for the others (remember that 0.5 is $Pr(Y=1|X)$)
#
# But some problems arise in interpreting the results in term of probability as after the estimation we can get values outside the probabilistc [0,1] interval
#
# Linear Regression is not the right model to use

# %% [markdown]
# Let's see what happen with a linear regression model

# %%
# default2 is the "Dummy" variable of 0 and 1. Balance is a real value predictor
model1 = smf.ols('default2 ~ balance', df)
est = model1.fit()
est.summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Now calculate $\hat y$ and interpret it as probability $P(Y=1|X)$

# %%
y_hat=est.predict(df.balance)

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)

# Set titles for the figure and the subplot respectively
fig.suptitle('Decision Boundary', fontsize=14, fontweight='bold')
#ax.set_title('axes title')

ax.set_xlabel('xlabel')
ax.set_ylabel('ylabel')

# regression line
ax.plot(df.balance.values,y_hat, c='blue')
# decision boundary
plt.plot([0,2500],[0.5,0.5], c='red') # decision boundary
# true value
ax.scatter(df.balance,df.default2, c='orange')

ax.text(2100, 0.35, 'Regression line', style='italic', bbox={'facecolor': 'blue', 'alpha': 0.5, 'pad': 6})
ax.text(300, 0.60, 'DECISION BOUNDARY Y>0.5 defaulted', style='italic', bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 6})
ax.text(2000, 0.88, 'TRUE DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6})
ax.text(1800, 0.07, 'TRUE NON-DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6})

ax.set_ylabel('Predicted Values');
ax.set_xlabel('Balance');
ax.set_yticks([0, 0.25, 0.5, 0.75, 1.]);

# %% [markdown]
# WE CAN NOTE THAT THE REGRESSION LINE IS ALWAYS BELOW THE DECISION BOUNDARY SO WE SHOULD CLASSIFY ALL THE FEATURES AS NON DEFAULTED AS CLASS 0 (FOR EVERY POINT IS P(Y=1|X)< 0.5)
#
# MOREOVER WE OBTAINED NEGATIVE PROBABILITY!
#
# What can we do?

# %% [markdown]
# ## LOGISTIC REGRESSION

# %% [markdown]
# CONSIDERING THE DIFFERENT APPROACHES WE ARE IN CASE 2.1
#
# we will use a PROBABILISTIC MODEL to make inference and we will model the PROBABILITY $P(C_k|X)$ DIRECTLY - this is an example of DISCRIMINATIVE MODEL

# %% [markdown]
# In our case we simplify and consider only TWO CLASSES - 0 and 1
#
# We're looking for a relation between PROBABILITY $Pr(Y|X)$ and $X$ where range of Y are 2 numbers: {0,1}
#
# We should model with a function that gives as output a number in the interval [0,1] in order to consider that as a probabilty
#
# Many functions meet this description
# In logistic regression we choose: $P(Y=1|X) = \sigma (\beta_0 + \bar \beta_1 * X)$
#
# Where $\sigma$ is the LOGISTIC SIGMOID $1/(1+exp(-x))$ and $P(Y=0|X) = 1 - P(Y=1|X)$
#
# In machine learning this is called activation function while statisticians call it inverse of the link function. Logist function always gives sensible predictions due to its form
#
# Now take a moment and reflect on the P(Y=1|X).
#
# Once we have fitted our model and found $\bar \beta$'s, $P(Y=1|X)$ is the probabilistic predictor we are looking for.
#
# How does this predictor work?
#
# Note that for a given X in the training data, we already now the correspondent TRUE class, because that is exactly the data we use to train the model and find the parameters $\hat \beta$'s. Let's say 1.
#
# After fitting the model, we can use the same X as input of my predictor to estimate a probability that the correspondent class is 0 or 1. As the TRUE class was 1, I expect that $P(Y=1|X)$ is very close to one. But the power of the predictor is that I can predict the class for a new value of X. Of course the results depends on how I fit the model and on the data I have.
#
# AS I have a PROBABILISTIC predictor of course I can use the power of inference to evaluate the estimates of the unknown parameter, the variance of the prediction, the residuals...!!
#
# But take care that ones we have a PROBABILISTIC PREDICTOR we STILL HAVE TO GO THROUGH A DECISION PROCESS. We have to fix a THRESHOLD on our predicted probability above which we decide to assign the input to class 1 or 0.
#
# For example. Suppose that for a given X you got $P(Y=1|X) =0.65$. So my predictor say that based on the fitted model (so based on the information I used to train it) we have a probability of 65% that that feature produce a class 1 and 35%, a class 0. Now, what decision would you take? Class 1 ? May be you can fix a threshold to 0.5. In this case it is a class 1. but you can choose to fix a threshold to 0.75 so in this case your decision would be class 0. You always must go through a decision step.
#
# Take care that because the relationship between $P(Y=1|X)$  and X, IS NOT LINEAR, $\beta_1$ does not corresponds to the change in P(Y=1|X)  associated with a one-unit increase in X
#
# FITTING THE MODEL - SOME THEORY
#
# To fit the model and calculate the unknown parameters is nice to use the power of the Maximum Likelihood Estimator.
#
# Question. What is the likelihood function?
#
# In our case we have 2 classes. Our random variable Y can assume only 2 values: 0 and 1
#
# a nice PROBABILISTIC model for this situation is to consider a BERNOULLI distribution.
# $Ber(Y|\mu) = \mu^y (1-\mu)^{1-y}$
#
# where $Y$ assumes only values $0$ and $1$, $\mu$ is the average of $Y$, $E(Y)=\mu$, and $VAR(Y)=\mu(1-\mu)$ (a classic example is a fair coin with $\mu=0.5$).
#
# Suppose we have a dataset $D=(y_1,y_2,...y_n)$ that we assume to be a realization of i.i.d. Y_n r.v. that are all the same $Y$ Bernoulli r.v. (technically that is a random sample - See Berger Statistical Inference cap. 5)
#
# We can construct the likelihood function for $p(D|\mu)$
#
# $p(D|\mu) = \prod_{i=1}^{N}p(y_i|\mu) = \prod_{i=1}^{N} \mu^{y_i} (1-\mu)^{1-y_i}$
#
# and log likelihood function is given by
#
# $ln(p(D|\mu)) = \sum_{i=1}^{N} ln(p(y_i|\mu)) = \sum_{i=1}^{N}[y_iln(\mu)+(1-y_i)ln(1-\mu)]$
#
# Now we only have to relax the CONSTANCE of $\mu$ (which for example represents the fairness of coin) and bind $\mu$ with our function, $\mu = Pr(Y=1|X) = \sigma (\beta_0 + \bar \beta_1 * X)$. In this way we bring the unknown coefficient into the likelihood and we can apply MLE to find coefficients
#
# How can i Maximize MLE?
#
# In the case of Logistic Regression there is NO LONGER A CLOSE FORM SOLUTION like in linear regression, due to NONLINEARITY of the logistic sigmoid. But the Error Function is still CONVEX and so we can use iterative COMPUTATIONAL technique like gradient descend, to compute the minimum.

# %% [markdown]
# ## Let's start with one feature

# %%
# Let's try with one feature - Balance
X_train = df.balance.values.reshape(-1,1) 
# true classes
y = df.default2

clf = skl_lm.LogisticRegression(solver='newton-cg')
clf.fit(X_train,y)

# calculate the prediction in train set
prob = clf.predict_proba(X_train)

# %%
# we can also use a different library with statistical values and do inference
X_train2 = sm.add_constant(df[['balance']])
est3 = smd.Logit(y, X_train2).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.079823
#          Iterations 10

# %%
est3.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                           Results: Logit
# ...
# Model:              Logit            Pseudo R-squared: 0.453
# Dependent Variable: default2         AIC:              1600.4517
# Date:               2021-05-03 17:59 BIC:              1614.8724
# No. Observations:   10000            Log-Likelihood:   -798.23
# Df Model:           1                LL-Null:          -1460.3
# Df Residuals:       9998             LLR p-value:      6.2329e-290
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     10.0000
# -------------------------------------------------------------------
#              Coef.    Std.Err.     z      P>|z|    [0.025    0.975]
# -------------------------------------------------------------------
# const       -10.6513    0.3612  -29.4913  0.0000  -11.3592  -9.9435
# balance       0.0055    0.0002   24.9524  0.0000    0.0051   0.0059
# ...
#
# """

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)

# Set titles for the figure and the subplot respectively
fig.suptitle('Predicted probability Pr(Y=1|X)', fontsize=14, fontweight='bold')

# plot the true value
X_v = X_train2.balance.values
ax.scatter(X_v, y, color='orange')

# plot predicted value
prob = est3.predict(X_train2)
ax.scatter(X_v, prob, color='lightblue')

ax.set_ylabel('Probability of P(Y=1|X=Balance)');
ax.set_xlabel('Balance');
ax.text(800, 0.50, 'Predicted Probability', style='italic', bbox={'facecolor': 'lightblue', 'alpha': 0.5, 'pad': 6})
ax.text(700, 0.88, 'TRUE DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6})
ax.text(1800, 0.07, 'TRUE NON-DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6});

# %%
prob
# Out:
# 0       0.001306
# 1       0.002113
# 2       0.008595
# 3       0.000434
# 4       0.001777
#           ...
# 9995    0.001183
# 9996    0.001526
# 9997    0.002467
# 9998    0.116760
# 9999    0.000071
# Length: 10000, dtype: float64

# %% [markdown]
# Let's Apply the DECISION RULE:
#
#
# $P(Y=1|X) >= 0.5$, $X$ belongs to class 1
#
# $P(Y=1|X) < 0.5$ $X$ belongs to class 0
#
# This choice is called the BAYES CLASSIFIER

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)

# Set titles for the figure and the subplot respectively
fig.suptitle('Predicted probability Pr(Y=1|X)', fontsize=14, fontweight='bold')

# plot the true value
X_v = X_train2.balance.values
ax.scatter(X_v, y, color='orange')

# plot predicted value
prob = est3.predict(X_train2)
ax.scatter(X_v, prob, color='lightblue')

ax.plot([0,2500],[0.5,0.5], c='red') # decision boundary
ax.plot([1920,1920],[0,1], 'g--', c='blue') # class boundary

ax.set_ylabel('Probability of P(Y=1|X=Balance)');
ax.set_xlabel('Balance');
ax.text(50, 0.58, 'DECISION BOUNDARY - PR(Y=1|X)>0.5', style='italic', bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 6})
ax.text(2000, -0.35, 'CLASSIFIED DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6})
ax.text(300, -0.35, 'CLASSIFIED NON DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6});
ax.text(1000, 0.9, 'MISCLASSIFICATION', style='italic', bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 4});
ax.text(2000, 0.07, 'MISCLASSIFICATION', style='italic', bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 4});

# %% [markdown]
# The red Line is the DECISION boundary line. Above this line, predictor $X$ is classified to belong to CLASS 1. Below this line IT is classified to belong to class 0
# #Dashed red line is the class boundary line. Input vector on the left are classified 0, on the right 1

# %% [markdown]
# I want now to measure the performance of my classifier

# %%
y_target = np.zeros(len(y_ptrain))

# create the vector of PREDICTED CLASSES BASED ON MY DECISION RULE
for i in range(len(y_ptrain)):
    if prob[i] >= 0.5:
        y_target[i] = 1

# %%
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: default2, Length: 10000, dtype: int64

# %%
#Generate confusion matrixes (Train and Test) and print main indicators
print('\n'.join(['\t'.join([str(cell) for cell in row]) for row in [['TN', 'FP'],['FN','TP']]]))

#generate confusion matrixes
cm_train = confusion_matrix(y,y_target)

hm = sns.heatmap(cm_train,cbar=True,annot=True,square=True,fmt='d',annot_kws={'size': 12},cmap = sns.diverging_palette(220, 10, as_cmap=True))
plt.title('Training set', fontsize=14)

plt.tight_layout()
plt.show()

REC1 = recall_score(y,y_target)
FP=cm_train[0][1]
TN=cm_train[0][0]
FPR1 = FP/(FP+TN)

print('Precision = {0:5.4f}'.format(precision_score(y,y_target)))
print('Recall= {0:5.4f}'.format(recall_score(y,y_target)))
print('F1-score= {0:5.4f}'.format(f1_score(y,y_target)))
print('Accuracy = {0:5.4f}'.format(accuracy_score(y,y_target)))
print('AUC = {0:5.4f}'.format(roc_auc_score(y,y_target)))
# Out:
# TN	FP
# FN	TP
# Precision = 0.7042
# Recall= 0.3003
# F1-score= 0.4211
# Accuracy = 0.9725
# AUC = 0.6480

# %% [markdown]
# We have BETTER results compared with the deterministic classifier.
#
# But...suppose that, as I'm a doctor, I want to avoid the FN (think on a diagnose!!). I want to RISE my recall.
#
# Can I CHANGE my decision in order to have less FN in line on what I need.

# %% [markdown]
# Let's Apply the below decision rule:
#
# $P() >= 0.25$ class 1
#
# $P()< 0.25$ class 0
#
# What happen?

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)

# Set titles for the figure and the subplot respectively
fig.suptitle('Predicted probability Pr(Y=1|X)', fontsize=14, fontweight='bold')

# plot the true value
X_v = X_train2.balance.values
ax.scatter(X_v, y, color='orange')

# plot predicted value
prob = est3.predict(X_train2)
ax.scatter(X_v, prob, color='lightblue')

ax.plot([0,2500],[0.25,0.25], c='red') # decision boundary
ax.plot([1730,1730],[0,1], 'g--', c='blue') # class boundary

ax.set_ylabel('Probability of P(Y=1|X=Balance)');
ax.set_xlabel('Balance');
ax.text(0, 0.32, 'DECISION BOUNDARY - PR(Y=1|X)>0.25', style='italic', bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 4})
ax.text(2000, -0.35, 'CLASSIFIED DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6})
ax.text(300, -0.35, 'CLASSIFIED NON DEFAULTED', style='italic', bbox={'facecolor': 'orange', 'alpha': 0.5, 'pad': 6});
ax.text(700, 0.9, 'MISCLASSIFICATION', style='italic', bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 4});
ax.text(2000, 0.07, 'MISCLASSIFICATION', style='italic', bbox={'facecolor': 'yellow', 'alpha': 0.5, 'pad': 4});

# %%
y_target = np.zeros(len(y_ptrain))

# create the vector of PREDICTED CLASSES BASED ON MY DECISION RULE
for i in range(len(y_ptrain)):
    # now I set 0.25
    if prob[i] >= 0.25:
        y_target[i] = 1

# %%
# %matplotlib inline
#Generate confusion matrixes (Train and Test) and print main indicators
print('\n'.join(['\t'.join([str(cell) for cell in row]) for row in [['TN', 'FP'],['FN','TP']]]))

#generate confusion matrixes
cm_train = confusion_matrix(y,y_target)

hm = sns.heatmap(cm_train,cbar=True,annot=True,square=True,fmt='d',annot_kws={'size': 12},cmap = sns.diverging_palette(220, 10, as_cmap=True))
plt.title('Training set', fontsize=14)

REC2 = recall_score(y,y_target)
FP=cm_train[0][1]
TN=cm_train[0][0]
FPR2 = FP/(FP+TN)
#plt.tight_layout()
#plt.show()

print('Precision = {0:5.4f}'.format(precision_score(y,y_target)))
print('Recall= {0:5.4f}'.format(recall_score(y,y_target)))
print('F1-score= {0:5.4f}'.format(f1_score(y,y_target)))
print('Accuracy = {0:5.4f}'.format(accuracy_score(y,y_target)))
print('AUC = {0:5.4f}'.format(roc_auc_score(y,y_target)));
# Out:
# TN	FP
# FN	TP
# Precision = 0.4816
# Recall= 0.5495
# F1-score= 0.5133
# Accuracy = 0.9653
# AUC = 0.7646

# %% [markdown]
# This is fine. With a 0.25 boundary i got 150 FP and the recall is higher than the bayes threshold. Of course I have to pay something. My accuracy is worst and also my precision drop a lot. I have a lot of false positive. But this is not important for me. In the end my patient will do more exams but it's fine.

# %% [markdown]
# My I have a look of the beaviuor of the rates with different values of the threshold?

# %% [markdown]
# ## Receiver operating characteristic  - ROC

# %% [markdown]
# A receiver operating characteristic curve, or ROC curve, is a graphical plot that illustrates the diagnostic ability of a binary classifier system as its DISCRIMINATION THRESHOLD IS VARIED.
#
# The ROC curve is created by plotting
# - the TRUE POSITIVE RATE against the FALSE POSITIVE RATE (FPR) at various threshold settings. The true-positive rate is also known as SENSITIVITY, RECALL or PROBABILITY OF DETECTION in machine learning. TPR = TP/(TP+FN). - The THE FALSE POSITIVE RATE (FPR) is also known as PROBABILITY OF FALSE ALARM and can be calculated as (1 − SPECIFICITY). FPR = FP/(TN+FP)
#
# Una curva ROC è il grafico dell'insieme delle coppie (FP, TP) al variare di un parametro del classificatore. Per esempio, in un classificatore a soglia, si calcola la frazione di veri positivi e quella di falsi positivi per ogni possibile valore della soglia; tutti i punti così ottenuti nello spazio FP-TP descrivono la curva ROC.
#
# ![image.png](attachment:image.png)
#
# The ROC space for a "better" and "worse" classifier.
# ![image-3.png](attachment:image-3.png)
#
# When using normalized units, the area under the curve (often referred to as simply the AUC) is equal to the probability that a classifier will rank a randomly chosen positive instance higher than a randomly chosen negative one (assuming 'positive' ranks higher than 'negative')

# %%
REC2 = recall_score(y,y_target)
FP=cm_train[0][1]
TN=cm_train[0][0]
FPR2 = FP/(FP+TN)
print('Recall1=',REC1)
print('Recall2=',REC2)

print('FPR1 = ',FPR1)
print('FPR2 = ',FPR2)
# Out:
# Recall1= 0.3003003003003003
# Recall2= 0.5495495495495496
# FPR1 =  0.004344677769732078
# FPR2 =  0.004344677769732078

# %%
import sklearn.metrics as metrics
# calculate the fpr and tpr for all thresholds of the classification

fpr, tpr, threshold = metrics.roc_curve(y, prob[:])
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate (RECALL)')
plt.xlabel('False Positive Rate')
plt.plot(FPR1,REC1, 'ro', c='blue')
plt.plot(FPR2,REC2, 'ro', c='green')

plt.show()

# %% [markdown]
# ## LOGISTIC REGRESSION WITH MORE THAN 1 PREDICTOR

# %% [markdown]
# Now let's try to fit with 2 predictors

# %%
X_train = sm.add_constant(df[['balance', 'income']])
est2 = smd.Logit(y, X_train).fit()
est2.summary2().tables[1]
# Out:
# Optimization terminated successfully.
#          Current function value: 0.078948
#          Iterations 10
#              Coef.  Std.Err.          z          P>|z|     [0.025     0.975]
# const   -11.540468  0.434772 -26.543696  3.036732e-155 -12.392607 -10.688330
# balance   0.005647  0.000227  24.835379  3.720520e-136   0.005201   0.006093
# income    0.000021  0.000005   4.174113   2.991499e-05   0.000011   0.000031

# %% [markdown]
# In logistic regression we choose: $P(Y=1|X) = \sigma (\beta_0 + \bar \beta_1 * X)$
#
# Our DECISION BOUNDARY (Bays classifier) is defined as $0.5 = \sigma (\beta_0 + \bar \beta_1 * X)$ so
#
# $ln(1/2) = ln(\sigma (\beta_0 + \beta_1^1 * Balance + \beta_1^2*Income)$ )
#
# $Income = -(ln(2) + \beta_0 + Balance*\beta_1^1) / \beta_1^2$
#
# PLEASE NOTE THAT WE STILL HAVE A LINEAR BOUNDARY !!

# %%
# I define a function to calculate 2 points in the boundary line
def line2 (x):
    return (-np.log(2)-est2.params[0]-est2.params[1]*x)/est2.params[2]

x3=1650
x4=2100
y3 = line2(x3)
y4 = line2(x4)
print(y3,y4)
# Out:
# 73506.80956021533 -48613.39400783308

# %%
# plot the boundary
fig = plt.figure(figsize=(25,10))
gs = mpl.gridspec.GridSpec(1, 4)
ax1 = plt.subplot(gs[0,:-2])

#Let's plot the dafault = YES
ax1.scatter(df_[df_.default == 'Yes'].balance, df_[df_.default == 'Yes'].income, s=40, c='orange', marker='+',
            linewidths=1)

#In the same plot ax1 we plot also the default=NO
ax1.scatter(df_[df_.default == 'No'].balance, df_[df_.default == 'No'].income, s=40, marker='o', linewidths='1',
            edgecolors='blue', facecolors='white', alpha=.3)


plt.plot([x3,x4],[y3,y4], c='red')
plt.plot([x1,x2],[y1,y2], c='blue')


# we set the axes of ax1
ax1.set_ylim(ymin=0)
ax1.set_ylabel('Income')
ax1.set_xlim(xmin=-100)
ax1.set_xlabel('Balance')

ax1.text(400, 70000, 'DETERMINISTIC BOUNDARY - PR(Y=1|X)>0', style='italic', bbox={'facecolor': 'blue', 'alpha': 0.5, 'pad': 4})
ax1.text(1800, 70000, 'PROBABILISTIC BOUNDARY - PR(Y=1|X)>0.5', style='italic', bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 6})
# Out:
# Text(1800, 70000, 'PROBABILISTIC BOUNDARY - PR(Y=1|X)>0.5')

# %%
y_ptrain= est2.predict(X_train)

# %%
y_target = np.zeros(len(y_ptrain))

# create the vector of PREDICTED CLASSES BASED ON MY DECISION RULE
for i in range(len(y_ptrain)):
    # now I set 0.5
    if y_ptrain[i] >= 0.5:
        y_target[i] = 1

# %%
#Generate confusion matrixes (Train and Test) and print main indicators
print('\n'.join(['\t'.join([str(cell) for cell in row]) for row in [['TN', 'FP'],['FN','TP']]]))

#generate confusion matrixes
cm_train = confusion_matrix(y,y_target)

hm = sns.heatmap(cm_train,cbar=True,annot=True,square=True,fmt='d',annot_kws={'size': 12},cmap = sns.diverging_palette(220, 10, as_cmap=True))
plt.title('Training set', fontsize=14)

plt.tight_layout()
plt.show()

print('Precision = {0:5.4f}'.format(precision_score(y,y_target)))
print('Recall= {0:5.4f}'.format(recall_score(y,y_target)))
print('F1-score= {0:5.4f}'.format(f1_score(y,y_target)))
print('Accuracy = {0:5.4f}'.format(accuracy_score(y,y_target)))
print('AUC = {0:5.4f}'.format(roc_auc_score(y,y_target)))
# Out:
# TN	FP
# FN	TP
# Precision = 0.7397
# Recall= 0.3243
# F1-score= 0.4509
# Accuracy = 0.9737
# AUC = 0.6602

# %% [markdown]
# With 2 predictors we have a little bit improvement respect one feature

# %% [markdown]
# ###  What with three predictors?

# %%
X_train = sm.add_constant(df[['balance', 'income', 'student2']])
# we use here a dummy variable

est = smd.Logit(y, X_train).fit()
est.summary2().tables[1]
# Out:
# Optimization terminated successfully.
#          Current function value: 0.078577
#          Iterations 10
#               Coef.  Std.Err.          z          P>|z|     [0.025    0.975]
# const    -10.869045  0.492273 -22.079320  4.995499e-108 -11.833882 -9.904209
# balance    0.005737  0.000232  24.736506  4.331521e-135   0.005282  0.006191
# income     0.000003  0.000008   0.369808   7.115254e-01  -0.000013  0.000019
# student2  -0.646776  0.236257  -2.737595   6.189022e-03  -1.109831 -0.183721

# %% [markdown]
# TABLE 4.3. For the Default data, estimated coefficients of the logistic regression model that predicts the probability of default using balance, income, and student status. Student status is encoded as a dummy variable student[Yes], with a value of 1 for a student and a value of 0 for a non-student. In fitting this model, income was measured in thousands of dollars.

# %% [markdown]
# The negative coefficient for student in
# the multiple logistic regression indicates that for a fixed value of balance
# and income , a student is less likely to default than a non-student.
# Take care of it
