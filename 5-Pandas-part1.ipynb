# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Il file dei dati contiene i dettagli dei terremoti avvenuti tra il -2150 a.C. e il 2023 d.C. Questo contiene informazioni sulla posizione, registrazioni del terremoto insieme alla menzione del numero di persone morte, feriti, descrizione dei danni e case distrutte. Poiché ciò comporta dati dalla storia. All'inizio molti dati sono nulli / inaccurati ma la latitudine e la longitudine dovrebbero essere l'area di interesse
#
# SOURCES
# National Geophysical Data Center / World Data Service (NGDC/WDS): NCEI/WDS Global Significant Earthquake Database. NOAA National Centers for Environmental Information. doi:10.7289/V5TD9V7K
#
# Scaricabile da:
# https://www.kaggle.com/

# %%
# !ls
# Out:
#  0-introduzione-generale.ipynb	        5-Pandas-part1.ipynb
#  1-assignment-Lezione1.ipynb	        data
#  1-hello-world-jupyter.ipynb	        fig
#  2-assignment-Lezione2.ipynb	        indice.ipynb
#  2-conditional-statements-loop.ipynb    lesson4.zip
# '3-assignment-Lezione 3.ipynb'	        LICENSE
#  3-Numpy-parte1.ipynb		        README.md
# '4-Numpy-parte2-Linear Algebra.ipynb'   video

# %%
# Caricamento del file CSV
df = pd.read_csv('./data/earthquakes.csv')

# %%
df
# Out:
#         Year   Mo    Dy    Hr    Mn   Sec     Tsu     Vol  \
# 0        NaN  NaN   NaN   NaN   NaN   NaN     NaN     NaN
# 1    -2150.0  NaN   NaN   NaN   NaN   0.0     NaN     NaN
# 2    -2000.0  NaN   NaN   NaN   NaN   NaN     1.0     NaN
# 3    -2000.0  NaN   NaN   NaN   NaN   NaN     NaN     NaN
# 4    -1610.0  NaN   NaN   NaN   NaN   NaN     3.0  1351.0
# ...      ...  ...   ...   ...   ...   ...     ...     ...
# 6345  2023.0  1.0  28.0  18.0  14.0  45.0     NaN     NaN
# 6346  2023.0  2.0   6.0   1.0  17.0  35.0  5873.0     NaN
# 6347  2023.0  2.0   6.0  10.0  24.0  49.0     NaN     NaN
# 6348  2023.0  2.0   9.0   6.0  28.0   0.0     NaN     NaN
# 6349  2023.0  2.0  20.0  17.0   4.0  29.0     NaN     NaN
#
#                                     Location Name  Latitude  ...  \
# 0                                             NaN       NaN  ...
# 1                   JORDAN:  BAB-A-DARAA,AL-KARAK    31.100  ...
# 2                                  SYRIA:  UGARIT    35.683  ...
# ...
