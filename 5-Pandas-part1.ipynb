# %% [markdown]
# # QUICK RECAP
#
#     Nella scorsa lezione abbiamo visto:
#     - Come gestire le celle di tipo MarkDown
#     - Array indexing e slicing di vettori e matrici: come accedere a singoli elementi di array
#     - Rudimenti di algebra delle matrici: somma, prodotto per scalare, prodotto scalare tra vettori e matrici
#     - Come calcolare il determinante di una matrice

# %%
# vediamo alcuni esempi
import numpy as np
a = np.random.randint(0,100, (10,10))

# %%
a[1:4,:]
# Out:
# array([[94,  8, 26, 67,  4, 13, 78, 73, 21, 72],
#        [80, 64, 45, 83, 52,  2,  5, 67, 93,  9],
#        [97, 60, 89, 68, 49, 27, 57, 80, 70, 32]])

# %% [markdown]
# # LA LIBRERIA PANDAS
# Nelle lezioni precedenti abbiamo visto la libreria NumPy e il tipo ndarray che consente di manipolare efficacemente array di numeri. Pandas è una libreria più recente, basata su NumPy, che fornisce un nuovo tipo di oggetto, il **DataFrame**. I DataFrame sono essenzialmente matrici multidimensionali che però hanno una "etichette" sulle righe e sulle colonne e possono ospitare tipi eterogenei (gli ndarray di numpy possono ospitare dati dello stesso tipo) e/o dati mancanti.I dataframe sono quindi comodi per la gestione dei dati.
#
# Importiamo ora la libreria Pandas

# %%
import pandas as pd

# %% [markdown]
# # BANCHE DATI
# La libreria Pandas consente di manipolare banche dati.
# Possiamo creare banche dati direttamente, come abbiamo fatto con la creazione degli array di Numpy, ma proviamo ad importare in Pandas una banca dati esistente.
#
# In particolare importeremo i dati di un file che contiene i dettagli dei terremoti avvenuti tra il -2150 a.C. e il 2023 d.C. Questo file contiene varie informazioni sui terremoti quali la posizione geografica, il momento in cui si è verificato, il numero di persone morte, feriti, descrizione dei danni e case distrutte. Poiché nel file ci sono dati storici, i primi dati incompleti.
#
# ### FONTI
# National Geophysical Data Center / World Data Service (NGDC/WDS): NCEI/WDS Global Significant Earthquake Database. NOAA National Centers for Environmental Information. doi:10.7289/V5TD9V7K
#
# Scaricabile da:
# https://www.kaggle.com/
#
# ### FORMATO DEL FILE
# Il formato del file è CSV che rappresenta uno dei modi più semplici per rappresentare dati in forma tabellare all'interno di un semplice file di testo.

# %%
# Caricamento del file CSV
df = pd.read_csv('./data/earthquakes.csv')

# %% [markdown]
# # **Nota per chi usa Google Colab**
#
# Il modo più semplice per caricare un file CSV in Google Colab è da un repository GitHub. Nel repository, fare clic sul file di dati, quindi fare clic su Visualizza Raw. Copia l'url che vedi nel browser e inseriscilo nel notebook Colab in una variabile denominata url, come mostrato di seguito. Utilizza quindi read_csv di Pandas per importare il file in un dataframe.
#
# url = 'inserisci qui la stringa dell'url copiata in github'
#
# df1 = pd.read_csv(url)

# %%
# PER CHI USA GITHUB: scommentare le seguenti due righe 
url = 'https://raw.githubusercontent.com/giandopal/Artificial-Intelligence-with-Python/main/data/earthquakes.csv'
df = pd.read_csv(url)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Notiamo il tipo DATAFRAME: è l'oggetto fondamentale della libreria PANDAS

# %%
# vediamo cosa abbiamo caricato
df
# Out:
#         Year   Mo    Dy    Hr    Mn   Sec     Tsu     Vol  \
# 0        NaN  NaN   NaN   NaN   NaN   NaN     NaN     NaN
# 1    -2150.0  NaN   NaN   NaN   NaN   0.0     NaN     NaN
# 2    -2000.0  NaN   NaN   NaN   NaN   NaN     1.0     NaN
# 3    -2000.0  NaN   NaN   NaN   NaN   NaN     NaN     NaN
# 4    -1610.0  NaN   NaN   NaN   NaN   NaN     3.0  1351.0
# ...      ...  ...   ...   ...   ...   ...     ...     ...
# 6345  2023.0  1.0  28.0  18.0  14.0  45.0     NaN     NaN
# 6346  2023.0  2.0   6.0   1.0  17.0  35.0  5873.0     NaN
# 6347  2023.0  2.0   6.0  10.0  24.0  49.0     NaN     NaN
# 6348  2023.0  2.0   9.0   6.0  28.0   0.0     NaN     NaN
# 6349  2023.0  2.0  20.0  17.0   4.0  29.0     NaN     NaN
#
#                                     Location Name  Latitude  ...  \
# 0                                             NaN       NaN  ...
# 1                   JORDAN:  BAB-A-DARAA,AL-KARAK    31.100  ...
# 2                                  SYRIA:  UGARIT    35.683  ...
# 3                                TURKMENISTAN:  W    38.000  ...
# 4               GREECE:  THERA ISLAND (SANTORINI)    36.400  ...
# ...                                           ...       ...  ...
# 6345                          IRAN:  KHVOY (KHOY)    38.424  ...
# 6346                                TURKEY; SYRIA    37.166  ...
# 6347                                TURKEY; SYRIA    38.024  ...
# 6348  INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA    -2.635  ...
# 6349                                TURKEY; SYRIA    36.109  ...
#
#       Total Missing  Total Missing Description  Total Injuries  \
# 0               NaN                        NaN             NaN
# 1               NaN                        NaN             NaN
# 2               NaN                        NaN             NaN
# 3               NaN                        NaN             NaN
# 4               NaN                        NaN             NaN
# ...             ...                        ...             ...
# 6345            NaN                        NaN          1017.0
# 6346            NaN                        NaN        206300.0
# 6347            NaN                        NaN             NaN
# 6348            NaN                        NaN             NaN
# 6349            NaN                        NaN           200.0
#
#       Total Injuries Description  Total Damage ($Mil)  \
# 0                            NaN                  NaN
# 1                            NaN                  NaN
# 2                            NaN                  NaN
# 3                            NaN                  NaN
# 4                            NaN                  NaN
# ...                          ...                  ...
# 6345                         4.0                  NaN
# 6346                         4.0                  NaN
# 6347                         NaN                  NaN
# 6348                         NaN                  NaN
# 6349                         3.0                  NaN
#
#       Total Damage Description  Total Houses Destroyed  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          1.0                     NaN
# 4                          3.0                     NaN
# ...                        ...                     ...
# 6345                       3.0                   370.0
# 6346                       4.0                100000.0
# 6347                       NaN                     NaN
# 6348                       1.0                    15.0
# 6349                       NaN                     NaN
#
#       Total Houses Destroyed Description  Total Houses Damaged  \
# 0                                    NaN                   NaN
# 1                                    NaN                   NaN
# 2                                    NaN                   NaN
# 3                                    1.0                   NaN
# 4                                    NaN                   NaN
# ...                                  ...                   ...
# 6345                                 3.0                   NaN
# 6346                                 4.0                   NaN
# 6347                                 NaN                   NaN
# 6348                                 1.0                  28.0
# 6349                                 NaN                   NaN
#
#       Total Houses Damaged Description
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# ...                                ...
# 6345                               4.0
# 6346                               4.0
# 6347                               NaN
# 6348                               1.0
# 6349                               NaN
#
# [6350 rows x 38 columns]

# %% [markdown]
# Il DataFrame ha un attributo indice che da accesso alle RIGHE

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6350, step=1)

# %% [markdown]
# Il DataFrame ha un attributo columns che da accesso alle COLONNE

# %%
df.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec', 'Tsu', 'Vol', 'Location Name',
#        'Latitude', 'Longitude', 'Focal Depth (km)', 'Mag', 'MMI Int', 'Deaths',
#        'Death Description', 'Missing', 'Missing Description', 'Injuries',
#        'Injuries Description', 'Damage ($Mil)', 'Damage Description',
#        'Houses Destroyed', 'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='object')

# %%
aa = df[['Mag', 'Deaths']]
aa.fillna(0)
import matplotlib.pyplot as plt
plt.plot(aa['Mag'],aa['Deaths'],'o')
plt.ylim(0,7000)
# Out:
# (0.0, 7000.0)

# %% [markdown]
# Mentre con Numpy non possiamo apporrre delle "Etichette" alle righe e alle colonne, con Pandas lo possiamo fare.
#
# Proviamo a cambiare l'etichetta delle righe

# %%
# i seguenti comandi sono un po' complicati, per ora limitatevi ad eseguirli 
new_index = [f'T_{i}' for i in range(len(df.index))]
df = df.rename(index=dict(zip(df.index, new_index)))

# %%
# osserviamo ora come ogni riga ha un'etichetta diversa
df
# Out:
#           Year   Mo    Dy    Hr    Mn   Sec     Tsu     Vol  \
# T_0        NaN  NaN   NaN   NaN   NaN   NaN     NaN     NaN
# T_1    -2150.0  NaN   NaN   NaN   NaN   0.0     NaN     NaN
# T_2    -2000.0  NaN   NaN   NaN   NaN   NaN     1.0     NaN
# T_3    -2000.0  NaN   NaN   NaN   NaN   NaN     NaN     NaN
# T_4    -1610.0  NaN   NaN   NaN   NaN   NaN     3.0  1351.0
# ...        ...  ...   ...   ...   ...   ...     ...     ...
# T_6345  2023.0  1.0  28.0  18.0  14.0  45.0     NaN     NaN
# T_6346  2023.0  2.0   6.0   1.0  17.0  35.0  5873.0     NaN
# T_6347  2023.0  2.0   6.0  10.0  24.0  49.0     NaN     NaN
# T_6348  2023.0  2.0   9.0   6.0  28.0   0.0     NaN     NaN
# T_6349  2023.0  2.0  20.0  17.0   4.0  29.0     NaN     NaN
#
#                                       Location Name  Latitude  ...  \
# T_0                                             NaN       NaN  ...
# T_1                   JORDAN:  BAB-A-DARAA,AL-KARAK    31.100  ...
# T_2                                  SYRIA:  UGARIT    35.683  ...
# T_3                                TURKMENISTAN:  W    38.000  ...
# T_4               GREECE:  THERA ISLAND (SANTORINI)    36.400  ...
# ...                                             ...       ...  ...
# T_6345                          IRAN:  KHVOY (KHOY)    38.424  ...
# T_6346                                TURKEY; SYRIA    37.166  ...
# T_6347                                TURKEY; SYRIA    38.024  ...
# T_6348  INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA    -2.635  ...
# T_6349                                TURKEY; SYRIA    36.109  ...
#
#         Total Missing  Total Missing Description  Total Injuries  \
# T_0               NaN                        NaN             NaN
# T_1               NaN                        NaN             NaN
# T_2               NaN                        NaN             NaN
# T_3               NaN                        NaN             NaN
# T_4               NaN                        NaN             NaN
# ...               ...                        ...             ...
# T_6345            NaN                        NaN          1017.0
# T_6346            NaN                        NaN        206300.0
# T_6347            NaN                        NaN             NaN
# T_6348            NaN                        NaN             NaN
# T_6349            NaN                        NaN           200.0
#
#         Total Injuries Description  Total Damage ($Mil)  \
# T_0                            NaN                  NaN
# T_1                            NaN                  NaN
# T_2                            NaN                  NaN
# T_3                            NaN                  NaN
# T_4                            NaN                  NaN
# ...                            ...                  ...
# T_6345                         4.0                  NaN
# T_6346                         4.0                  NaN
# T_6347                         NaN                  NaN
# T_6348                         NaN                  NaN
# T_6349                         3.0                  NaN
#
#         Total Damage Description  Total Houses Destroyed  \
# T_0                          NaN                     NaN
# T_1                          NaN                     NaN
# T_2                          NaN                     NaN
# T_3                          1.0                     NaN
# T_4                          3.0                     NaN
# ...                          ...                     ...
# T_6345                       3.0                   370.0
# T_6346                       4.0                100000.0
# T_6347                       NaN                     NaN
# T_6348                       1.0                    15.0
# T_6349                       NaN                     NaN
#
#         Total Houses Destroyed Description  Total Houses Damaged  \
# T_0                                    NaN                   NaN
# T_1                                    NaN                   NaN
# T_2                                    NaN                   NaN
# T_3                                    1.0                   NaN
# T_4                                    NaN                   NaN
# ...                                    ...                   ...
# T_6345                                 3.0                   NaN
# T_6346                                 4.0                   NaN
# T_6347                                 NaN                   NaN
# T_6348                                 1.0                  28.0
# T_6349                                 NaN                   NaN
#
#         Total Houses Damaged Description
# T_0                                  NaN
# T_1                                  NaN
# T_2                                  NaN
# T_3                                  NaN
# T_4                                  NaN
# ...                                  ...
# T_6345                               4.0
# T_6346                               4.0
# T_6347                               NaN
# T_6348                               1.0
# T_6349                               NaN
#
# [6350 rows x 38 columns]

# %% [markdown]
# # Come possiamo avere una visione complessiva della nostra tabella?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6350 entries, T_0 to T_6349
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                6349 non-null   float64
#  1   Mo                                  5939 non-null   float64
#  2   Dy                                  5783 non-null   float64
#  3   Hr                                  4300 non-null   float64
#  4   Mn                                  4095 non-null   float64
#  5   Sec                                 4390 non-null   float64
#  6   Tsu                                 1958 non-null   float64
#  7   Vol                                 77 non-null     float64
#  8   Location Name                       6348 non-null   object
#  9   Latitude                            6297 non-null   float64
#  10  Longitude                           6297 non-null   float64
#  11  Focal Depth (km)                    3384 non-null   float64
#  12  Mag                                 4574 non-null   float64
#  13  MMI Int                             3062 non-null   float64
#  14  Deaths                              2130 non-null   float64
#  15  Death Description                   2613 non-null   float64
#  16  Missing                             26 non-null     float64
#  17  Missing Description                 26 non-null     float64
#  18  Injuries                            1348 non-null   float64
#  19  Injuries Description                1573 non-null   float64
#  20  Damage ($Mil)                       546 non-null    float64
#  21  Damage Description                  4594 non-null   float64
#  22  Houses Destroyed                    857 non-null    float64
#  23  Houses Destroyed Description        1849 non-null   float64
#  24  Houses Damaged                      543 non-null    float64
#  25  Houses Damaged Description          1073 non-null   float64
#  26  Total Deaths                        1939 non-null   float64
#  27  Total Death Description             2310 non-null   float64
#  28  Total Missing                       29 non-null     float64
#  29  Total Missing Description           33 non-null     float64
#  30  Total Injuries                      1369 non-null   float64
#  31  Total Injuries Description          1594 non-null   float64
#  32  Total Damage ($Mil)                 521 non-null    float64
#  33  Total Damage Description            3683 non-null   float64
#  34  Total Houses Destroyed              889 non-null    float64
#  35  Total Houses Destroyed Description  1931 non-null   float64
#  36  Total Houses Damaged                487 non-null    float64
#  37  Total Houses Damaged Description    964 non-null    float64
# dtypes: float64(37), object(1)
# memory usage: 1.9+ MB

# %%
# Proviamo a estrarre una COLONNA
df['Year']
# Out:
# T_0          NaN
# T_1      -2150.0
# T_2      -2000.0
# T_3      -2000.0
# T_4      -1610.0
#            ...
# T_6345    2023.0
# T_6346    2023.0
# T_6347    2023.0
# T_6348    2023.0
# T_6349    2023.0
# Name: Year, Length: 6350, dtype: float64

# %%
# Proviamo a estrarre due COLONNE

df[['Location Name','Year']]
# Out:
#                                       Location Name    Year
# T_0                                             NaN     NaN
# T_1                   JORDAN:  BAB-A-DARAA,AL-KARAK -2150.0
# T_2                                  SYRIA:  UGARIT -2000.0
# T_3                                TURKMENISTAN:  W -2000.0
# T_4               GREECE:  THERA ISLAND (SANTORINI) -1610.0
# ...                                             ...     ...
# T_6345                          IRAN:  KHVOY (KHOY)  2023.0
# T_6346                                TURKEY; SYRIA  2023.0
# T_6347                                TURKEY; SYRIA  2023.0
# T_6348  INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA  2023.0
# T_6349                                TURKEY; SYRIA  2023.0
#
# [6350 rows x 2 columns]

# %% [markdown]
# Facciamo attenzione a non confonderci con gli ndarray

# %%
a = np.random.randint(0,100, (10,10))
a[0]
# in questo caso estraggo la prima riga
# Out:
# array([63, 65, 39, 39, 79, 19, 92, 41,  6, 13])

# %% [markdown]
# Come possiamo accedere ad un singolo elemento del DataFrame?
# Come per gli ndarray possiamo utilizzare la notazione [x,y], utilizzando il metodo iloc. Ricordiamo che la numerazione parte da [0,0]

# %%
df.iloc[1,0]
# Out:
# -2150.0

# %% [markdown]
# Possiamo utilizzare lo slicing [:,1:4]

# %%
# estraiamo la seconda riga
df.iloc[5500,:]
# Out:
# Year                                           2007.0
# Mo                                               11.0
# Dy                                                6.0
# Hr                                                9.0
# Mn                                               38.0
# Sec                                               5.7
# Tsu                                               NaN
# Vol                                               NaN
# Location Name                         INDIA:  GUJARAT
# Latitude                                       21.181
# Longitude                                      70.724
# Focal Depth (km)                                 10.0
# Mag                                               5.1
# MMI Int                                           NaN
# Deaths                                            1.0
# Death Description                                 1.0
# Missing                                           NaN
# Missing Description                               NaN
# Injuries                                          5.0
# Injuries Description                              1.0
# Damage ($Mil)                                     NaN
# Damage Description                                1.0
# Houses Destroyed                                  NaN
# Houses Destroyed Description                      2.0
# Houses Damaged                                    NaN
# Houses Damaged Description                        2.0
# Total Deaths                                      1.0
# Total Death Description                           1.0
# Total Missing                                     NaN
# Total Missing Description                         NaN
# Total Injuries                                    5.0
# Total Injuries Description                        1.0
# Total Damage ($Mil)                               NaN
# Total Damage Description                          1.0
# Total Houses Destroyed                            NaN
# Total Houses Destroyed Description                2.0
# Total Houses Damaged                              NaN
# Total Houses Damaged Description                  NaN
# Name: T_5500, dtype: object

# %%
# estraiamo la seconda nona colonna
df.iloc[:,8]
# Out:
# T_0                                               NaN
# T_1                     JORDAN:  BAB-A-DARAA,AL-KARAK
# T_2                                    SYRIA:  UGARIT
# T_3                                  TURKMENISTAN:  W
# T_4                 GREECE:  THERA ISLAND (SANTORINI)
#                              ...
# T_6345                            IRAN:  KHVOY (KHOY)
# T_6346                                  TURKEY; SYRIA
# T_6347                                  TURKEY; SYRIA
# T_6348    INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA
# T_6349                                  TURKEY; SYRIA
# Name: Location Name, Length: 6350, dtype: object

# %%
# estraiamo dalla 3a alla 7a riga e dalla 9a alla 10a colonna
df.iloc[2:6,8:10]
# Out:
#                          Location Name  Latitude
# T_2                     SYRIA:  UGARIT    35.683
# T_3                   TURKMENISTAN:  W    38.000
# T_4  GREECE:  THERA ISLAND (SANTORINI)    36.400
# T_5           ISRAEL:  ARIHA (JERICHO)    31.500

# %%
df.iloc[[2,5,7],[3,4,9]]
# Out:
#      Hr  Mn  Latitude
# T_2 NaN NaN    35.683
# T_5 NaN NaN    31.500
# T_7 NaN NaN    35.683

# %% [markdown]
# Posso anche utilizzare le label delle colonne

# %%
# estraggo dalla colonna Latitude le righe da 2 a 3
df['Latitude'][1:3]
# Out:
# T_1    31.100
# T_2    35.683
# Name: Latitude, dtype: float64

# %% [markdown]
# Le colonne del dataframe sono anche FIELD dell'oggetto dataframe.
# Possiamo quindi utilizzare il comando df.fields

# %%
df.Latitude
# Out:
# T_0          NaN
# T_1       31.100
# T_2       35.683
# T_3       38.000
# T_4       36.400
#            ...
# T_6345    38.424
# T_6346    37.166
# T_6347    38.024
# T_6348    -2.635
# T_6349    36.109
# Name: Latitude, Length: 6350, dtype: float64

# %% [markdown]
# ## ORA PROVA TU
# - Estrai dalla tabella le righe che vanno da 1500 a 1520
# - Estrai dalla tabella la colonna 'Latitude' e 'Death'
# - Estrai le righe da 4500 a 4700 delle colonne 'Latitude' e 'Death'
# - Estrai tutte le righe dalla colonna 4a alla fine
# - estra tutte le informazioni corrispondenti alla riga 4200

# %% [markdown]
# ## Vediamo ora come eseguire filtri sul dataframe per estrarre qualche informazione dalla tabella

# %%
df.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec', 'Tsu', 'Vol', 'Location Name',
#        'Latitude', 'Longitude', 'Focal Depth (km)', 'Mag', 'MMI Int', 'Deaths',
#        'Death Description', 'Missing', 'Missing Description', 'Injuries',
#        'Injuries Description', 'Damage ($Mil)', 'Damage Description',
#        'Houses Destroyed', 'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='object')

# %%
# Proviamo a prendere una sola colonna
year = df['Year']

# %%
year
# Out:
# T_0          NaN
# T_1      -2150.0
# T_2      -2000.0
# T_3      -2000.0
# T_4      -1610.0
#            ...
# T_6345    2023.0
# T_6346    2023.0
# T_6347    2023.0
# T_6348    2023.0
# T_6349    2023.0
# Name: Year, Length: 6350, dtype: float64

# %%
# Osserviamo il tipo di una colonna
type(year)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Il tipo di una singola colonna è **Series**

# %% [markdown]
# ## estraiamo una decina di RIGHE

# %%
# estraiamo una decina di RIGHE
b = year.iloc[1000:1010]

# %%
b
# Out:
# T_1000    1674.0
# T_1001    1675.0
# T_1002    1676.0
# T_1003    1677.0
# T_1004    1677.0
# T_1005    1677.0
# T_1006    1677.0
# T_1007    1677.0
# T_1008    1678.0
# T_1009    1678.0
# Name: Year, dtype: float64

# %% [markdown]
# ## voglio controllare quali righe hanno il valore 1677

# %%
b == 1677
# Out:
# T_1000    False
# T_1001    False
# T_1002    False
# T_1003     True
# T_1004     True
# T_1005     True
# T_1006     True
# T_1007     True
# T_1008    False
# T_1009    False
# Name: Year, dtype: bool

# %% [markdown]
# # noto che il controllo mi restituisce TRUE su ogni riga in cui è verificata la condizione.
#
# ## Chiaramente posso utilizzare gli operatori logici

# %%
b
# Out:
# T_1000    1674.0
# T_1001    1675.0
# T_1002    1676.0
# T_1003    1677.0
# T_1004    1677.0
# T_1005    1677.0
# T_1006    1677.0
# T_1007    1677.0
# T_1008    1678.0
# T_1009    1678.0
# Name: Year, dtype: float64

# %%
(1676 < b) & (b < 1678)
# Out:
# T_1000    False
# T_1001    False
# T_1002    False
# T_1003     True
# T_1004     True
# T_1005     True
# T_1006     True
# T_1007     True
# T_1008    False
# T_1009    False
# Name: Year, dtype: bool

# %% [markdown]
# ## La cosa interessante è che se applico il filtro all'intero dataframe, ottengo il filtro sulla tabella

# %%
year = df['Year']
filtro = year == 2023

# %%
filtro
# Out:
# T_0       False
# T_1       False
# T_2       False
# T_3       False
# T_4       False
#           ...
# T_6345     True
# T_6346     True
# T_6347     True
# T_6348     True
# T_6349     True
# Name: Year, Length: 6350, dtype: bool

# %%
df_filtrato = df[filtro]
df_filtrato
# Out:
#           Year   Mo    Dy    Hr    Mn   Sec     Tsu  Vol  \
# T_6343  2023.0  1.0   9.0  17.0  47.0  35.0  5871.0  NaN
# T_6344  2023.0  1.0  24.0   8.0  58.0  32.0     NaN  NaN
# T_6345  2023.0  1.0  28.0  18.0  14.0  45.0     NaN  NaN
# T_6346  2023.0  2.0   6.0   1.0  17.0  35.0  5873.0  NaN
# T_6347  2023.0  2.0   6.0  10.0  24.0  49.0     NaN  NaN
# T_6348  2023.0  2.0   9.0   6.0  28.0   0.0     NaN  NaN
# T_6349  2023.0  2.0  20.0  17.0   4.0  29.0     NaN  NaN
#
#                                             Location Name  Latitude  ...  \
# T_6343                              INDONESIA:  BANDA SEA    -7.049  ...
# T_6344  INDIA: UTTAR PRADESH; NEPAL: SUDURPASHCHIM PRO...    29.597  ...
# T_6345                                IRAN:  KHVOY (KHOY)    38.424  ...
# T_6346                                      TURKEY; SYRIA    37.166  ...
# T_6347                                      TURKEY; SYRIA    38.024  ...
# T_6348        INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA    -2.635  ...
# T_6349                                      TURKEY; SYRIA    36.109  ...
#
#         Total Missing  Total Missing Description  Total Injuries  \
# T_6343            NaN                        NaN             NaN
# T_6344            NaN                        NaN             NaN
# T_6345            NaN                        NaN          1017.0
# T_6346            NaN                        NaN        206300.0
# T_6347            NaN                        NaN             NaN
# T_6348            NaN                        NaN             NaN
# T_6349            NaN                        NaN           200.0
#
#         Total Injuries Description  Total Damage ($Mil)  \
# T_6343                         NaN                  NaN
# T_6344                         1.0                  NaN
# T_6345                         4.0                  NaN
# T_6346                         4.0                  NaN
# T_6347                         NaN                  NaN
# T_6348                         NaN                  NaN
# T_6349                         3.0                  NaN
#
#         Total Damage Description  Total Houses Destroyed  \
# T_6343                       2.0                    37.0
# T_6344                       2.0                     NaN
# T_6345                       3.0                   370.0
# T_6346                       4.0                100000.0
# T_6347                       NaN                     NaN
# T_6348                       1.0                    15.0
# T_6349                       NaN                     NaN
#
#         Total Houses Destroyed Description  Total Houses Damaged  \
# T_6343                                 1.0                 327.0
# T_6344                                 1.0                  42.0
# T_6345                                 3.0                   NaN
# T_6346                                 4.0                   NaN
# T_6347                                 NaN                   NaN
# T_6348                                 1.0                  28.0
# T_6349                                 NaN                   NaN
#
#         Total Houses Damaged Description
# T_6343                               3.0
# T_6344                               1.0
# T_6345                               4.0
# T_6346                               4.0
# T_6347                               NaN
# T_6348                               1.0
# T_6349                               NaN
#
# [7 rows x 38 columns]

# %% [markdown]
# ##  Possiamo utilizzare anche una sintassi più accorpata

# %%
df_filtrato = df[df['Year']==1677]
df_filtrato
# Out:
#           Year    Mo    Dy    Hr    Mn  Sec    Tsu  Vol  \
# T_1003  1677.0   4.0  13.0   NaN   NaN  NaN  321.0  NaN
# T_1004  1677.0   9.0   NaN   NaN   NaN  NaN    NaN  NaN
# T_1005  1677.0  11.0   4.0   NaN   NaN  NaN  322.0  NaN
# T_1006  1677.0  12.0   7.0  11.0  30.0  NaN  323.0  NaN
# T_1007  1677.0   NaN   NaN   NaN   NaN  0.0    NaN  NaN
#
#                           Location Name  Latitude  ...  Total Missing  \
# T_1003                  JAPAN:  SANRIKU      40.0  ...            NaN
# T_1004           CHINA:  GANSU PROVINCE      33.4  ...            NaN
# T_1005   JAPAN:  OFF SE. BOSO PENINSULA      35.0  ...            NaN
# T_1006  PHILIPPINES:  LUZON:  CENTRAL,S      14.5  ...            NaN
# T_1007             JAMAICA:  PORT ROYAL      17.6  ...            NaN
#
#         Total Missing Description  Total Injuries  Total Injuries Description  \
# T_1003                        NaN             NaN                         NaN
# T_1004                        NaN             NaN                         NaN
# T_1005                        NaN             NaN                         NaN
# T_1006                        NaN             NaN                         3.0
# T_1007                        NaN             NaN                         NaN
#
#         Total Damage ($Mil)  Total Damage Description  Total Houses Destroyed  \
# T_1003                  NaN                       1.0                     NaN
# T_1004                  NaN                       1.0                     NaN
# T_1005                  NaN                       3.0                  1001.0
# T_1006                  NaN                       1.0                     NaN
# T_1007                  NaN                       NaN                     NaN
#
#         Total Houses Destroyed Description  Total Houses Damaged  \
# T_1003                                 1.0                   NaN
# T_1004                                 NaN                   NaN
# T_1005                                 4.0                   NaN
# T_1006                                 NaN                   NaN
# T_1007                                 NaN                   NaN
#
#         Total Houses Damaged Description
# T_1003                               NaN
# T_1004                               NaN
# T_1005                               NaN
# T_1006                               1.0
# T_1007                               NaN
#
# [5 rows x 38 columns]

# %%
# Operatore and
df_filtrato = df[(df['Year']>1675)&(df['Year']<1680)]
df_filtrato
# Out:
#           Year    Mo    Dy    Hr    Mn  Sec    Tsu     Vol  \
# T_1002  1676.0   7.0  12.0   NaN   NaN  0.0    NaN     NaN
# T_1003  1677.0   4.0  13.0   NaN   NaN  NaN  321.0     NaN
# T_1004  1677.0   9.0   NaN   NaN   NaN  NaN    NaN     NaN
# T_1005  1677.0  11.0   4.0   NaN   NaN  NaN  322.0     NaN
# T_1006  1677.0  12.0   7.0  11.0  30.0  NaN  323.0     NaN
# T_1007  1677.0   NaN   NaN   NaN   NaN  0.0    NaN     NaN
# T_1008  1678.0   2.0   3.0   NaN   NaN  0.0    NaN     NaN
# T_1009  1678.0   2.0  11.0  14.0   NaN  0.0    NaN     NaN
# T_1010  1678.0   2.0  23.0   NaN   NaN  0.0    NaN     NaN
# T_1011  1678.0   6.0  18.0   1.0  45.0  NaN  325.0     NaN
# T_1012  1678.0  10.0   2.0   NaN   NaN  0.0    NaN     NaN
# T_1013  1678.0   NaN   NaN   NaN   NaN  NaN    NaN     NaN
# T_1014  1679.0   6.0   4.0   NaN   NaN  0.0    NaN     NaN
# T_1015  1679.0   9.0   2.0   NaN   NaN  NaN    NaN     NaN
# T_1016  1679.0   9.0  21.0   NaN   NaN  NaN    NaN  4969.0
# T_1017  1679.0  12.0  16.0   NaN   NaN  NaN    NaN     NaN
#
#                                          Location Name  Latitude  ...  \
# T_1002                                  JAPAN:  TUWANO      34.5  ...
# T_1003                                 JAPAN:  SANRIKU      40.0  ...
# T_1004                          CHINA:  GANSU PROVINCE      33.4  ...
# T_1005                  JAPAN:  OFF SE. BOSO PENINSULA      35.0  ...
# T_1006                 PHILIPPINES:  LUZON:  CENTRAL,S      14.5  ...
# T_1007                            JAMAICA:  PORT ROYAL      17.6  ...
# T_1008                                  IRAN:  LAHIJAN      37.1  ...
# T_1009                         CUBA:  SANTIAGO DE CUBA      20.0  ...
# T_1010                                  IRAN:  GONABAD      34.2  ...
# T_1011  PERU:  LIMA,SALINAS-HUAURA,LIMA,CALLAO,CHANCAY      -9.0  ...
# T_1012                         JAPAN:  SANRIKU,RIKUCHU      38.6  ...
# T_1013                      INDIA:  KASHMIR:  SRINAGAR      34.1  ...
# T_1014                         TURKEY; ARMENIA:  DVINA      40.1  ...
# T_1015                          CHINA:  HEBEI PROVINCE      40.0  ...
# T_1016                                YEMEN:  AL MUKHA      13.3  ...
# T_1017                        CHINA:  JIANGSU PROVINCE      31.4  ...
#
#         Total Missing  Total Missing Description  Total Injuries  \
# T_1002            NaN                        NaN             NaN
# T_1003            NaN                        NaN             NaN
# T_1004            NaN                        NaN             NaN
# T_1005            NaN                        NaN             NaN
# T_1006            NaN                        NaN             NaN
# T_1007            NaN                        NaN             NaN
# T_1008            NaN                        NaN             NaN
# T_1009            NaN                        NaN             NaN
# T_1010            NaN                        NaN             NaN
# T_1011            NaN                        NaN             NaN
# T_1012            NaN                        NaN             NaN
# T_1013            NaN                        NaN             NaN
# T_1014            NaN                        NaN             NaN
# T_1015            NaN                        NaN             NaN
# T_1016            NaN                        NaN             NaN
# T_1017            NaN                        NaN             NaN
#
#         Total Injuries Description  Total Damage ($Mil)  \
# T_1002                         NaN                  NaN
# T_1003                         NaN                  NaN
# T_1004                         NaN                  NaN
# T_1005                         NaN                  NaN
# T_1006                         3.0                  NaN
# T_1007                         NaN                  NaN
# T_1008                         NaN                  NaN
# T_1009                         NaN                  NaN
# T_1010                         NaN                  NaN
# T_1011                         NaN                  NaN
# T_1012                         NaN                  NaN
# T_1013                         NaN                  NaN
# T_1014                         NaN                  NaN
# T_1015                         NaN                  NaN
# T_1016                         NaN                  NaN
# T_1017                         NaN                  NaN
#
#         Total Damage Description  Total Houses Destroyed  \
# T_1002                       NaN                     NaN
# T_1003                       1.0                     NaN
# T_1004                       1.0                     NaN
# T_1005                       3.0                  1001.0
# T_1006                       1.0                     NaN
# T_1007                       NaN                     NaN
# T_1008                       NaN                     NaN
# T_1009                       NaN                     NaN
# T_1010                       NaN                     NaN
# T_1011                       3.0                     NaN
# T_1012                       NaN                     NaN
# T_1013                       2.0                     NaN
# T_1014                       NaN                     NaN
# T_1015                       4.0                     NaN
# T_1016                       1.0                     NaN
# T_1017                       1.0                     NaN
#
#         Total Houses Destroyed Description  Total Houses Damaged  \
# T_1002                                 NaN                   NaN
# T_1003                                 1.0                   NaN
# T_1004                                 NaN                   NaN
# T_1005                                 4.0                   NaN
# T_1006                                 NaN                   NaN
# T_1007                                 NaN                   NaN
# T_1008                                 NaN                   NaN
# T_1009                                 NaN                   NaN
# T_1010                                 NaN                   NaN
# T_1011                                 3.0                   NaN
# T_1012                                 NaN                   NaN
# T_1013                                 2.0                   NaN
# T_1014                                 NaN                   NaN
# T_1015                                 4.0                   NaN
# T_1016                                 NaN                   NaN
# T_1017                                 1.0                   NaN
#
#         Total Houses Damaged Description
# T_1002                               NaN
# T_1003                               NaN
# T_1004                               NaN
# T_1005                               NaN
# T_1006                               1.0
# T_1007                               NaN
# T_1008                               NaN
# T_1009                               NaN
# T_1010                               NaN
# T_1011                               NaN
# T_1012                               NaN
# T_1013                               NaN
# T_1014                               NaN
# T_1015                               NaN
# T_1016                               NaN
# T_1017                               NaN
#
# [16 rows x 38 columns]

# %%
# operatore OR
df_filtrato = df[(df['Year']==1677) | (df['Year']==1679)]
df_filtrato
# Out:
#           Year    Mo    Dy    Hr    Mn  Sec    Tsu     Vol  \
# T_1003  1677.0   4.0  13.0   NaN   NaN  NaN  321.0     NaN
# T_1004  1677.0   9.0   NaN   NaN   NaN  NaN    NaN     NaN
# T_1005  1677.0  11.0   4.0   NaN   NaN  NaN  322.0     NaN
# T_1006  1677.0  12.0   7.0  11.0  30.0  NaN  323.0     NaN
# T_1007  1677.0   NaN   NaN   NaN   NaN  0.0    NaN     NaN
# T_1014  1679.0   6.0   4.0   NaN   NaN  0.0    NaN     NaN
# T_1015  1679.0   9.0   2.0   NaN   NaN  NaN    NaN     NaN
# T_1016  1679.0   9.0  21.0   NaN   NaN  NaN    NaN  4969.0
# T_1017  1679.0  12.0  16.0   NaN   NaN  NaN    NaN     NaN
#
#                           Location Name  Latitude  ...  Total Missing  \
# T_1003                  JAPAN:  SANRIKU      40.0  ...            NaN
# T_1004           CHINA:  GANSU PROVINCE      33.4  ...            NaN
# T_1005   JAPAN:  OFF SE. BOSO PENINSULA      35.0  ...            NaN
# T_1006  PHILIPPINES:  LUZON:  CENTRAL,S      14.5  ...            NaN
# T_1007             JAMAICA:  PORT ROYAL      17.6  ...            NaN
# T_1014          TURKEY; ARMENIA:  DVINA      40.1  ...            NaN
# T_1015           CHINA:  HEBEI PROVINCE      40.0  ...            NaN
# T_1016                 YEMEN:  AL MUKHA      13.3  ...            NaN
# T_1017         CHINA:  JIANGSU PROVINCE      31.4  ...            NaN
#
#         Total Missing Description  Total Injuries  Total Injuries Description  \
# T_1003                        NaN             NaN                         NaN
# T_1004                        NaN             NaN                         NaN
# T_1005                        NaN             NaN                         NaN
# T_1006                        NaN             NaN                         3.0
# T_1007                        NaN             NaN                         NaN
# T_1014                        NaN             NaN                         NaN
# T_1015                        NaN             NaN                         NaN
# T_1016                        NaN             NaN                         NaN
# T_1017                        NaN             NaN                         NaN
#
#         Total Damage ($Mil)  Total Damage Description  Total Houses Destroyed  \
# T_1003                  NaN                       1.0                     NaN
# T_1004                  NaN                       1.0                     NaN
# T_1005                  NaN                       3.0                  1001.0
# T_1006                  NaN                       1.0                     NaN
# T_1007                  NaN                       NaN                     NaN
# T_1014                  NaN                       NaN                     NaN
# T_1015                  NaN                       4.0                     NaN
# T_1016                  NaN                       1.0                     NaN
# T_1017                  NaN                       1.0                     NaN
#
#         Total Houses Destroyed Description  Total Houses Damaged  \
# T_1003                                 1.0                   NaN
# T_1004                                 NaN                   NaN
# T_1005                                 4.0                   NaN
# T_1006                                 NaN                   NaN
# T_1007                                 NaN                   NaN
# T_1014                                 NaN                   NaN
# T_1015                                 4.0                   NaN
# T_1016                                 NaN                   NaN
# T_1017                                 1.0                   NaN
#
#         Total Houses Damaged Description
# T_1003                               NaN
# T_1004                               NaN
# T_1005                               NaN
# T_1006                               1.0
# T_1007                               NaN
# T_1014                               NaN
# T_1015                               NaN
# T_1016                               NaN
# T_1017                               NaN
#
# [9 rows x 38 columns]

# %% [markdown]
# # ORA PROVA TU
# - Estrai dalla tabella le righe dell'anno 1948
# - Estrai dalla tabella le righe dagli anni 2000 al 2015
# - Estrai dalla tabella le righe che hanno un numero di morti (colonna Death) maggiore di 1000
# - Estrai dalla tabella le righe che hanno un numero di morti maggiore di 1000 tra gli anni 2000 e 2015

# %%
df1 = df[(df['Year']<2024) & (df['Year']>2000)]

# %%
df2 = df1[df['Deaths']>1000]
# Out:
# /tmp/ipykernel_53622/2767790333.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df1[df['Deaths']>1000]

# %%
df2[['Year','Deaths','Location Name']]
# Out:
#           Year    Deaths                                      Location Name
# T_5091  2001.0   20005.0  INDIA:  GUJARAT:  BHUJ, AHMADABAD, RAJOKOT; PA...
# T_5197  2003.0    2287.0       ALGERIA:  ALGIERS, BOUMERDES, REGHIA, THENIA
# T_5245  2003.0   31000.0                 IRAN:  SOUTHEASTERN:  BAM, BARAVAT
# T_5324  2004.0    1001.0        INDONESIA:  SUMATRA:  ACEH:  OFF WEST COAST
# T_5346  2005.0    1303.0                          INDONESIA:  SUMATERA:  SW
# T_5372  2005.0   76213.0   PAKISTAN:  MUZAFFARABAD, URI, ANANTNAG, BARAMULA
# T_5411  2006.0    5749.0             INDONESIA:   JAVA:  BANTUL, YOGYAKARTA
# T_5542  2008.0   87652.0                           CHINA:  SICHUAN PROVINCE
# T_5634  2009.0    1117.0                       INDONESIA:  SUMATRA:  PADANG
# T_5659  2010.0  316000.0                             HAITI:  PORT-AU-PRINCE
# T_5674  2010.0    2220.0                   CHINA:  QINGHAI PROVINCE:  YUSHU
# T_5726  2011.0    1475.0                                     JAPAN:  HONSHU
# T_5948  2015.0    8957.0       NEPAL:   KATHMANDU; INDIA; CHINA; BANGLADESH
# T_6154  2018.0    4340.0                               INDONESIA:  SULAWESI
# T_6289  2021.0    2248.0                                              HAITI
# T_6321  2022.0    1039.0            AFGHANISTAN: PAKTIKA PROVINCE; PAKISTAN
# T_6346  2023.0   48224.0                                      TURKEY; SYRIA

# %% [markdown]
# ## proviamo con una nazione: voglio estrarre tutte le righe che si riferiscono all'Italia

# %%
df['Location Name']
# Out:
# T_0                                               NaN
# T_1                     JORDAN:  BAB-A-DARAA,AL-KARAK
# T_2                                    SYRIA:  UGARIT
# T_3                                  TURKMENISTAN:  W
# T_4                 GREECE:  THERA ISLAND (SANTORINI)
#                              ...
# T_6345                            IRAN:  KHVOY (KHOY)
# T_6346                                  TURKEY; SYRIA
# T_6347                                  TURKEY; SYRIA
# T_6348    INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA
# T_6349                                  TURKEY; SYRIA
# Name: Location Name, Length: 6350, dtype: object

# %% [markdown]
# ## Sembra più complicato perchè abbiamo a che fare con delle stringhe

# %% [markdown]
# Prendiamo per esempio una riga

# %%
# prendo il contenuto della riga 1000 della colonna 'Location Name'
stringa = df['Location Name'][1000]

# %%
stringa
# Out:
# 'ECUADOR:  CHIMBORAZO,BOLIVAR,QUITO'

# %%
type(stringa)
# Out:
# str

# %% [markdown]
# Come faccio a controllare se una parola è nella stringa ? uso **in**

# %%
"ECUADOR" in stringa
# Out:
# True

# %% [markdown]
# Però non funziona con il dataframe

# %%
"ECUADOR" in df['Location Name']
# Out:
# False

# %% [markdown]
# Utilizzo il metodo str.contains

# %%
filtro_italy = df['Location Name'].str.contains("ITALY")

# %%
filtro_italy
# Out:
# T_0         NaN
# T_1       False
# T_2       False
# T_3       False
# T_4       False
#           ...
# T_6345    False
# T_6346    False
# T_6347    False
# T_6348    False
# T_6349    False
# Name: Location Name, Length: 6350, dtype: object

# %% [markdown]
# Ancora non va bene perchè abbiamo NaN... Ma cosa è NaN?

# %% [markdown]
# ## NaN: Not A Number
#
# Il valore NaN è utilizzato in Pandas per rappresentare un valore mancante.
# Ci sono diversi metodi tra cui riportiamo:
#
# - ``isnull()``: crea una maschera booleana mettendo in evidenza i NaN con True
# - ``notnull()``: l'opposto di ``isnull()``
# - ``dropna()``: restituisce una versione filtrata del dataframe senza NaN
# - ``fillna()``: restituisce una copia del dataframe con i dati NaN sostituiti da altri valori

# %%
df.isnull()
# Out:
#          Year     Mo     Dy     Hr     Mn    Sec    Tsu    Vol  Location Name  \
# T_0      True   True   True   True   True   True   True   True           True
# T_1     False   True   True   True   True  False   True   True          False
# T_2     False   True   True   True   True   True  False   True          False
# T_3     False   True   True   True   True   True   True   True          False
# T_4     False   True   True   True   True   True  False  False          False
# ...       ...    ...    ...    ...    ...    ...    ...    ...            ...
# T_6345  False  False  False  False  False  False   True   True          False
# T_6346  False  False  False  False  False  False  False   True          False
# T_6347  False  False  False  False  False  False   True   True          False
# T_6348  False  False  False  False  False  False   True   True          False
# T_6349  False  False  False  False  False  False   True   True          False
#
#         Latitude  ...  Total Missing  Total Missing Description  \
# T_0         True  ...           True                       True
# T_1        False  ...           True                       True
# T_2        False  ...           True                       True
# T_3        False  ...           True                       True
# T_4        False  ...           True                       True
# ...          ...  ...            ...                        ...
# T_6345     False  ...           True                       True
# T_6346     False  ...           True                       True
# T_6347     False  ...           True                       True
# T_6348     False  ...           True                       True
# T_6349     False  ...           True                       True
#
#         Total Injuries  Total Injuries Description  Total Damage ($Mil)  \
# T_0               True                        True                 True
# T_1               True                        True                 True
# T_2               True                        True                 True
# T_3               True                        True                 True
# T_4               True                        True                 True
# ...                ...                         ...                  ...
# T_6345           False                       False                 True
# T_6346           False                       False                 True
# T_6347            True                        True                 True
# T_6348            True                        True                 True
# T_6349           False                       False                 True
#
#         Total Damage Description  Total Houses Destroyed  \
# T_0                         True                    True
# T_1                         True                    True
# T_2                         True                    True
# T_3                        False                    True
# T_4                        False                    True
# ...                          ...                     ...
# T_6345                     False                   False
# T_6346                     False                   False
# T_6347                      True                    True
# T_6348                     False                   False
# T_6349                      True                    True
#
#         Total Houses Destroyed Description  Total Houses Damaged  \
# T_0                                   True                  True
# T_1                                   True                  True
# T_2                                   True                  True
# T_3                                  False                  True
# T_4                                   True                  True
# ...                                    ...                   ...
# T_6345                               False                  True
# T_6346                               False                  True
# T_6347                                True                  True
# T_6348                               False                 False
# T_6349                                True                  True
#
#         Total Houses Damaged Description
# T_0                                 True
# T_1                                 True
# T_2                                 True
# T_3                                 True
# T_4                                 True
# ...                                  ...
# T_6345                             False
# T_6346                             False
# T_6347                              True
# T_6348                             False
# T_6349                              True
#
# [6350 rows x 38 columns]

# %%
df.fillna("0")
# Out:
#           Year   Mo    Dy    Hr    Mn   Sec     Tsu     Vol  \
# T_0          0    0     0     0     0     0       0       0
# T_1    -2150.0    0     0     0     0   0.0       0       0
# T_2    -2000.0    0     0     0     0     0     1.0       0
# T_3    -2000.0    0     0     0     0     0       0       0
# T_4    -1610.0    0     0     0     0     0     3.0  1351.0
# ...        ...  ...   ...   ...   ...   ...     ...     ...
# T_6345  2023.0  1.0  28.0  18.0  14.0  45.0       0       0
# T_6346  2023.0  2.0   6.0   1.0  17.0  35.0  5873.0       0
# T_6347  2023.0  2.0   6.0  10.0  24.0  49.0       0       0
# T_6348  2023.0  2.0   9.0   6.0  28.0   0.0       0       0
# T_6349  2023.0  2.0  20.0  17.0   4.0  29.0       0       0
#
#                                       Location Name Latitude  ...  \
# T_0                                               0        0  ...
# T_1                   JORDAN:  BAB-A-DARAA,AL-KARAK     31.1  ...
# T_2                                  SYRIA:  UGARIT   35.683  ...
# T_3                                TURKMENISTAN:  W     38.0  ...
# T_4               GREECE:  THERA ISLAND (SANTORINI)     36.4  ...
# ...                                             ...      ...  ...
# T_6345                          IRAN:  KHVOY (KHOY)   38.424  ...
# T_6346                                TURKEY; SYRIA   37.166  ...
# T_6347                                TURKEY; SYRIA   38.024  ...
# T_6348  INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA   -2.635  ...
# T_6349                                TURKEY; SYRIA   36.109  ...
#
#        Total Missing Total Missing Description Total Injuries  \
# T_0                0                         0              0
# T_1                0                         0              0
# T_2                0                         0              0
# T_3                0                         0              0
# T_4                0                         0              0
# ...              ...                       ...            ...
# T_6345             0                         0         1017.0
# T_6346             0                         0       206300.0
# T_6347             0                         0              0
# T_6348             0                         0              0
# T_6349             0                         0          200.0
#
#        Total Injuries Description Total Damage ($Mil)  \
# T_0                             0                   0
# T_1                             0                   0
# T_2                             0                   0
# T_3                             0                   0
# T_4                             0                   0
# ...                           ...                 ...
# T_6345                        4.0                   0
# T_6346                        4.0                   0
# T_6347                          0                   0
# T_6348                          0                   0
# T_6349                        3.0                   0
#
#        Total Damage Description Total Houses Destroyed  \
# T_0                           0                      0
# T_1                           0                      0
# T_2                           0                      0
# T_3                         1.0                      0
# T_4                         3.0                      0
# ...                         ...                    ...
# T_6345                      3.0                  370.0
# T_6346                      4.0               100000.0
# T_6347                        0                      0
# T_6348                      1.0                   15.0
# T_6349                        0                      0
#
#        Total Houses Destroyed Description Total Houses Damaged  \
# T_0                                     0                    0
# T_1                                     0                    0
# T_2                                     0                    0
# T_3                                   1.0                    0
# T_4                                     0                    0
# ...                                   ...                  ...
# T_6345                                3.0                    0
# T_6346                                4.0                    0
# T_6347                                  0                    0
# T_6348                                1.0                 28.0
# T_6349                                  0                    0
#
#        Total Houses Damaged Description
# T_0                                   0
# T_1                                   0
# T_2                                   0
# T_3                                   0
# T_4                                   0
# ...                                 ...
# T_6345                              4.0
# T_6346                              4.0
# T_6347                                0
# T_6348                              1.0
# T_6349                                0
#
# [6350 rows x 38 columns]

# %% [markdown]
# ## Ora possiamo eliminare i NaN sostituendo un valore più trattabile. Mettiamo la stringa "0"

# %%
newdf = df.fillna("0")

# %%
newdf
# Out:
#           Year   Mo    Dy    Hr    Mn   Sec     Tsu     Vol  \
# T_0          0    0     0     0     0     0       0       0
# T_1    -2150.0    0     0     0     0   0.0       0       0
# T_2    -2000.0    0     0     0     0     0     1.0       0
# T_3    -2000.0    0     0     0     0     0       0       0
# T_4    -1610.0    0     0     0     0     0     3.0  1351.0
# ...        ...  ...   ...   ...   ...   ...     ...     ...
# T_6345  2023.0  1.0  28.0  18.0  14.0  45.0       0       0
# T_6346  2023.0  2.0   6.0   1.0  17.0  35.0  5873.0       0
# T_6347  2023.0  2.0   6.0  10.0  24.0  49.0       0       0
# T_6348  2023.0  2.0   9.0   6.0  28.0   0.0       0       0
# T_6349  2023.0  2.0  20.0  17.0   4.0  29.0       0       0
#
#                                       Location Name Latitude  ...  \
# T_0                                               0        0  ...
# T_1                   JORDAN:  BAB-A-DARAA,AL-KARAK     31.1  ...
# T_2                                  SYRIA:  UGARIT   35.683  ...
# T_3                                TURKMENISTAN:  W     38.0  ...
# T_4               GREECE:  THERA ISLAND (SANTORINI)     36.4  ...
# ...                                             ...      ...  ...
# T_6345                          IRAN:  KHVOY (KHOY)   38.424  ...
# T_6346                                TURKEY; SYRIA   37.166  ...
# T_6347                                TURKEY; SYRIA   38.024  ...
# T_6348  INDONESIA: NEW GUINEA: IRIAN JAYA: JAYAPURA   -2.635  ...
# T_6349                                TURKEY; SYRIA   36.109  ...
#
#        Total Missing Total Missing Description Total Injuries  \
# T_0                0                         0              0
# T_1                0                         0              0
# T_2                0                         0              0
# T_3                0                         0              0
# T_4                0                         0              0
# ...              ...                       ...            ...
# T_6345             0                         0         1017.0
# T_6346             0                         0       206300.0
# T_6347             0                         0              0
# T_6348             0                         0              0
# T_6349             0                         0          200.0
#
#        Total Injuries Description Total Damage ($Mil)  \
# T_0                             0                   0
# T_1                             0                   0
# T_2                             0                   0
# T_3                             0                   0
# T_4                             0                   0
# ...                           ...                 ...
# T_6345                        4.0                   0
# T_6346                        4.0                   0
# T_6347                          0                   0
# T_6348                          0                   0
# T_6349                        3.0                   0
#
#        Total Damage Description Total Houses Destroyed  \
# T_0                           0                      0
# T_1                           0                      0
# T_2                           0                      0
# T_3                         1.0                      0
# T_4                         3.0                      0
# ...                         ...                    ...
# T_6345                      3.0                  370.0
# T_6346                      4.0               100000.0
# T_6347                        0                      0
# T_6348                      1.0                   15.0
# T_6349                        0                      0
#
#        Total Houses Destroyed Description Total Houses Damaged  \
# T_0                                     0                    0
# T_1                                     0                    0
# T_2                                     0                    0
# T_3                                   1.0                    0
# T_4                                     0                    0
# ...                                   ...                  ...
# T_6345                                3.0                    0
# T_6346                                4.0                    0
# T_6347                                  0                    0
# T_6348                                1.0                 28.0
# T_6349                                  0                    0
#
#        Total Houses Damaged Description
# T_0                                   0
# T_1                                   0
# T_2                                   0
# T_3                                   0
# T_4                                   0
# ...                                 ...
# T_6345                              4.0
# T_6346                              4.0
# T_6347                                0
# T_6348                              1.0
# T_6349                                0
#
# [6350 rows x 38 columns]

# %% [markdown]
# ## Ora mettiamo il filtro sulla nazione Italia

# %%
filtro_italy = newdf['Location Name'].str.contains("ITALY")
filtro_italy
# Out:
# T_0       False
# T_1       False
# T_2       False
# T_3       False
# T_4       False
#           ...
# T_6345    False
# T_6346    False
# T_6347    False
# T_6348    False
# T_6349    False
# Name: Location Name, Length: 6350, dtype: bool

# %%
earthquake_italy.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_53622/3534979783.py in <module>
# ----> 1 earthquake_italy.info()
#
# NameError: name 'earthquake_italy' is not defined

# %%
earthquake_italy = newdf[filtro_italy]
earthquake_italy.tail(30)

# %%
earthquake_italy

# %% [markdown]
# # ORA PROVA TU:
# - Estrai dalla tabella in che anni c'è stato un terremoto in TURCHIA (TURKEY)
# - Estrai dalla tabella sopra i terremoti del 2023

# %%
filtro_turkey= (newdf['Location Name'].str.contains("TURK")) 
newdf[filtro_turkey]['Year']

# %%
tab_turchia=newdf[filtro_turkey]
#tab_turchia[newdf['Year']==2023]

# %% [markdown]
# Voglio calcolare il numero totali di morti a causa di un terremoto in Turchia

# %%
a3= tab_turchia['Deaths']

# %%
a3.sum()

# %% [markdown]
# Abbiamo un errore perchè nella colonna "Deaths" ho numeri in formato stringa. Devo convertirli

# %%
tab_turchia['Deaths'][20]

# %%
aa4 =tab_turchia['Deaths'].astype(float)

# %%
aa4.sum()

# %% [markdown]
# ## Voglio ora plottare il n. di morti per anno

# %%
tab_turchia

# %%
worktable = tab_turchia[['Year','Deaths']]

# %%
worktable

# %%
worktable.info()

# %%
# le colonne sono di tipo object. Le converto in int
worktable['Deaths'] = worktable['Deaths'].astype(float)
worktable['Year'] = worktable['Year'].astype(float)

# %%
worktable.info()

# %%
worktable

# %% [markdown]
# ## Ora possiamo utilizzare il comando groupby

# %%
work2 = worktable.groupby('Year')['Deaths'].sum()

# %%
work2

# %%
import matplotlib.pyplot as plt

# %%
# impostiamo una dimensione di 10 pollici di larghezza per 5 pollici di altezza
plt.figure(figsize=(15,10))

plt.plot(work2)

plt.xlim(1900,2023)
plt.ylim(0,100000)

plt.xlabel('Year')
plt.ylabel('Death')
plt.title('Number of Deaths in Turkey')

# %%
df.columns
# Out:
# Index(['Year', 'Mo', 'Dy', 'Hr', 'Mn', 'Sec', 'Tsu', 'Vol', 'Location Name',
#        'Latitude', 'Longitude', 'Focal Depth (km)', 'Mag', 'MMI Int', 'Deaths',
#        'Death Description', 'Missing', 'Missing Description', 'Injuries',
#        'Injuries Description', 'Damage ($Mil)', 'Damage Description',
#        'Houses Destroyed', 'Houses Destroyed Description', 'Houses Damaged',
#        'Houses Damaged Description', 'Total Deaths', 'Total Death Description',
#        'Total Missing', 'Total Missing Description', 'Total Injuries',
#        'Total Injuries Description', 'Total Damage ($Mil)',
#        'Total Damage Description', 'Total Houses Destroyed',
#        'Total Houses Destroyed Description', 'Total Houses Damaged',
#        'Total Houses Damaged Description'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6350 entries, T_0 to T_6349
# Data columns (total 38 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Year                                6349 non-null   float64
#  1   Mo                                  5939 non-null   float64
#  2   Dy                                  5783 non-null   float64
#  3   Hr                                  4300 non-null   float64
#  4   Mn                                  4095 non-null   float64
#  5   Sec                                 4390 non-null   float64
#  6   Tsu                                 1958 non-null   float64
#  7   Vol                                 77 non-null     float64
#  8   Location Name                       6348 non-null   object
#  9   Latitude                            6297 non-null   float64
#  10  Longitude                           6297 non-null   float64
#  11  Focal Depth (km)                    3384 non-null   float64
#  12  Mag                                 4574 non-null   float64
#  13  MMI Int                             3062 non-null   float64
#  14  Deaths                              2130 non-null   float64
#  15  Death Description                   2613 non-null   float64
#  16  Missing                             26 non-null     float64
#  17  Missing Description                 26 non-null     float64
#  18  Injuries                            1348 non-null   float64
#  19  Injuries Description                1573 non-null   float64
#  20  Damage ($Mil)                       546 non-null    float64
#  21  Damage Description                  4594 non-null   float64
#  22  Houses Destroyed                    857 non-null    float64
#  23  Houses Destroyed Description        1849 non-null   float64
#  24  Houses Damaged                      543 non-null    float64
#  25  Houses Damaged Description          1073 non-null   float64
#  26  Total Deaths                        1939 non-null   float64
#  27  Total Death Description             2310 non-null   float64
#  28  Total Missing                       29 non-null     float64
#  29  Total Missing Description           33 non-null     float64
#  30  Total Injuries                      1369 non-null   float64
#  31  Total Injuries Description          1594 non-null   float64
#  32  Total Damage ($Mil)                 521 non-null    float64
#  33  Total Damage Description            3683 non-null   float64
#  34  Total Houses Destroyed              889 non-null    float64
#  35  Total Houses Destroyed Description  1931 non-null   float64
#  36  Total Houses Damaged                487 non-null    float64
#  37  Total Houses Damaged Description    964 non-null    float64
# dtypes: float64(37), object(1)
# memory usage: 2.1+ MB
