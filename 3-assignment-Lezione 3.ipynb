# %% [markdown]
# 1.
# Sulla base dell'esempio fornito a lezione (check numeriprimi) sviluppare uno script che estrae i divisori di 7 da una lista contenente i numeri da 0 a 1000. Questi divisori devono essere archiviati in una specifica lista denominata listadivisori per un uso futuro.

# %% [markdown]
# 2.
# Sulla base dell'esempio fornito a lezione (cercaparola) sviluppare uno script che:
# 1) conta quante volte una data parola richiesta dall'utente è presente nel testo (l'utente inserisce la parola con il comando INPUT
# 2) Data una parola inserita dall'utente, stampa la parola precedente e la parola successiva alla parola data

# %% [markdown]
# 3. Fare qualche esercizio proposto sul sito https://www.w3resource.com/python-exercises/list/

# %% [markdown]
# 4. Scrivi un programma utilizzando NumPy che crea un array di 10 zeri,10 uni, 10 cinque

# %% [markdown]
# 5.  Write a NumPy program to generate an array of 15 random numbers

# %% [markdown]
# 6. Write a NumPy program to create a 3X4 array

# %% [markdown]
# 7. Plotta la funzione $y=x^3 - 2x^2 + x -2$ tra -3 e 3 utilizzando la vettorizzazione delle funzioni
#
# Ricorda che l'elevamento a potenza si fa con x**3

# %% [markdown]
# 8. Plotta la funzione $y=-2x^3 + x^2 - x +1$ tra -3 e 3 utilizzando la vettorizzazione delle funzioni
#
# Vedi la soluzione sotto

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(-3,3,100)
def myfunction(x):
    y = x**3-3*x**2+x-2
    return y
def myfunction2(x):
    y = -2*x**3+x**2-x+1
    return y
myfunc_vect = np.vectorize(myfunction)
myfunc_vect2 = np.vectorize(myfunction2)
y = myfunc_vect(x)
y2=myfunc_vect2(x)
plt.plot(x,y)
plt.plot(x,y2)
